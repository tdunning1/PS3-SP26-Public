# %% [markdown]
# # POLSCI 3 - Some practice questions
#
# In this version of the Notebook, **you can check the answers with an Otter cell in all cases.**
#
# **NOTE: These practice problems only cover a portion of the material from the course.  The final exam will certainly cover other material from the class, but these practice problems may be useful as they reflect the format and nature of some of the exam questions.**

# %% [markdown]
# ## Analyzing Experiments With Regression
#
# Let's practice using data from Problem Set 2 (from an experiment on the effect of social pressure mail on voter turnout from a [field experiment conducted by Alan Gerber, Greg Huber, Albert Fang, and Andrew Gooch](https://journals.sagepub.com/doi/abs/10.1177/1532673X16686556#abstract)).
#
# Remember that this experiment, conducted in South Dakota in the 2014 midterm elections, studied the effects of a "gentler" social pressure mailer than the experiment from the Michigan primary election in 2006 that we discussed in Week 5.  (You can look back at Problem Set 2 for a fuller description of the mailer, but that is not necessary to do these practice problems).
#
# First, load the data by running the following code chunk:

# %%
# Run this cell
library(testthat) # load the testthat package
library(estimatr) # load the estimatr package

gentle <- read.csv("ps2.csv") # read in the data

# Let's look at the structure of the data (shows the first six rows)
head(gentle)

# %% [markdown]
# ### Research Design and Variable Codebook
#
# In the experiment, voters were randomly assigned into the treatment group (`treat` variable = `1`) or the control group (`treat` variable = `0`).
#
# In the treatment group (`treat` variable = `1`), voters received a mailer aimed at creating social pressure for them to vote before the 2014 election. In the control group (`treat` variable = `0`), voters received no mail from the researchers.
#
# Then, based on public records from the government, the researchers coded whether the voter actually ended up voting in the variable `voted14`. Last, the researchers also coded the race and gender of the voters in `race_white` and `female` respectively.
#
# To recap, here are what the variables mean:
# - `treat`: `1` = voter received the gentle social pressure mailer (treatment group); `0` = voter did not receive the mailer (control group)
# - `voted14`: `1` = the voter voted in the 2014 midterm elections; `0` = the voter did not vote in the 2014 midterm elections. This is the outcome.
# - `race_white`: `1` = the voter is white; `0` = the voter is non-white
# - `female`: `1` = the voter is female; `0` = the voter is not female
#
# -----

# %% [markdown]
# ### The effects of the "gentle" social pressure mail
#
# We are going to start by doing some regression analysis of this dataset and interpreting the results.
#
# **Question 1 (1 point).** Using the summary() function with lm(), run a bivariate regression of `voted14` on `treat` with the `gentle` data.
#
# You will be able to check your answer using the Otter cell after the question.

# %%
# Replace "NULL # YOUR CODE HERE" with your code.
# Run the bivariate regression using summary() and lm()
bivariate_gentle <- NULL # YOUR CODE HERE
bivariate_gentle # print your result

# %%
. = ottr::check("tests/q1.R")

# %% [markdown]
# **Question 2a** What is the baseline or reference category in the regression results?  Choose the best answer (if only one of `'a'`, `'b'` or `'c'` is correct, choose that option; otherwise, choose one of the others).
#
# - `'a'` The control group;
# - `'b'` Voters for whom `treat`=0.
# - `'c'` Voters for whom `race_white` = 0 and `female`=0 (i.e. male voters who are not white).
# - `'d'` Both (a) and (b);
# - `'e'` Both (a) and (c);
# - `'f'` Both (b) and (c);
# - `'g'` All of (a), (b), and (c);
# - `'h'` None of the above.
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q2a.answer <- 'a'`.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q2a.answer <- '...'
q2a.answer # print your answer

# %%
. = ottr::check("tests/q2a.R")

# %% [markdown]
# **Question 2b** Consider the regression results in Question 1. What is the best interpretation of the results? Choose the best answer.
#
# - `'a'` About 22% of the voters in this experiment voted when they were not sent any mailer.
# - `'b'` About 24% of the voters in this experiment voted when they were sent the "gentle social pressure" mailer.
# - `'c'` The effect of the control condition is highly statistically significant.
# - `'d'` Our best guess is that the social pressure mail increased voter turnout by about (a rounded) 2 percentage points, although the actual true average treatment effect might be somewhat smaller or larger than that.
# - `'e'` (a) and (b);
# - `'f'` (a) and (c);
# - `'g'` (a) and (d);
# - `'h'` (b) and (c);
# - `'i'` (b) and (d);
# - `'j'` (c) and (d);
# - `'k'` (a), (b), and (c);
# - `'l`' (a), (b), and (d);
# - `'m'` (a), (c), and (d);
# - `'n'` (b), (c), and (d);
# - `'o'` None of the above.
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q2b.answer <- 'a'`.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q2b.answer <- '...'
q2b.answer # print your answer

# %%
. = ottr::check("tests/q2b.R")

# %% [markdown]
# ----
#
# The $p$-value for the coefficient on `treat` in the regression output in Question 1 was approximately as follows:

# %%
# RUN THIS CELL
round(bivariate_gentle$coefficients[2,4],5)

# %% [markdown]
# **Question 3.** What does this $p$-value mean?**
#
# - `'a'`: There is only an approximately 9\% chance we would obtain an estimate as large as the one we did if the mail had no effect.
# - `'b'`: The null hypothesis that the mailer in truth does not have an effect is true.
# - `'c'`: The alterative hypothesis that the mailer in truth has an effect is false.
# - `'d'`: Social scientists usually consider it unlikely that we would obtain an estimate as large as the one we did if the mail had no effect.
#
# Enter your answer between quotes. For example, if you wanted to answer `'a'`, you would type `q3.answer <- 'a'`.

# %%
q3.answer <- '...'
q3.answer # Print your answer

# %%
. = ottr::check("tests/q3.R")

# %% [markdown]
# **Question 4a.** Continue to consider the $p$-value you printed above for Question 3. `TRUE` or `FALSE`? This $p$-value is considered "statistically significant."
#
# Enter `TRUE` or `FALSE` below.
#
# (This must be in all caps with no quotes. E.g., to answer `TRUE`, type `q4a.answer <- TRUE`.)
#
# *Note: because this question is multiple choice, it will not tell you whether or not you got the right answer.*

# %%
q4a.answer <- NULL # YOUR CODE HERE

q4a.answer # Print your answer

# %%
. = ottr::check("tests/q4a.R")

# %% [markdown]
# Let's print the regression results again so that we have them at hand to answer the next question.

# %%
# Run this cell
bivariate_gentle # print your result

# %% [markdown]
# **Question 4b (1 point)** Which of the following **IS** a correct interpretation of the regression results?
#
# - `'a'` Our best guess is that receiving a "gentle" social pressure mailer causes about 2 voters out of 100 who would not have voted, had they not received any mailer at all, to vote.
# - `'b'` Our best guess is that receiving no mailer at all causes about 2 voters out of 100 who would have voted, had they received a mailer, not to vote.
# - `'c'` Our best guess is that about 22 out of every 100 voters who receive the gentle social pressure mailer decide to vote.
# - `'d'` Our best guess is that about 24 out of every 100 voters who receive no mailer at all decide to vote.
# - `'e'` None of the above.
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q3.answer <- 'a'`.

# %%
q4b.answer <- '...'
q4b.answer # Print your answer

# %%
. = ottr::check("tests/q4b.R")

# %% [markdown]
# **Question 5 (1 point)** Consider the `treat` row in the regression results above. Which of the following **IS** a correct interpretation of the results?
#
# - `'a'` The probability that the gentle social pressure treatment increases voting rates relative to the baseline is very high, as indicated by the large *t*-statistic in the `treat` row.
# - `'b'` The probability of finding the large *t*-statistic shown in the `treat` row is very low, if the gentle social pressure treatment does not increase voting rates relative to the baseline.
# - `'c'` There is more than a 95% probability that the gentle social pressure treatment increases voting rates, relative to the baseline.
# - `'d'` There is more than a 95% probability that the confidence interval for the gentle social pressure treatment does not include zero.
# - `'e'` None of the above.
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q5.answer <- 'a'`.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q5.answer <- '...'
q5.answer # print your answer

# %%
. = ottr::check("tests/q5.R")

# %% [markdown]
# **Question 6** Now, run a multivariate regression using syntax similar to the regression in Question 1, but now add the following additional independent variables: `race_white` and `female`.

# %%
# Run the multivariate regression using summary() and lm()
# Replace "NULL # YOUR CODE HERE" with your code.

multivariate_gentle <- NULL # YOUR CODE HERE
multivariate_gentle # print your result

# %%
. = ottr::check("tests/q6.R")

# %% [markdown]
# **Question 7.** Consider the estimate of about `0.0697` in the row for `female`. Which of the following **IS** a correct interpretation of the results?
#
# - `'a'` Being female causes voters to be about 7 percentage points more likely to vote in the election.
# - `'b'` Being female causes voters to be about 7 percentage points more likely to vote in the election, holding constant the other control variables in the regression.
# - `'c'` The probability that a voter is female will vote in the  election is about 7 percentage points higher than a voter who is male.
# - `'d'` The probability that a voter is female will vote in the  election is about 7 percentage points higher than a voter who is male, holding constant the other control variable in the regression.
# - `'e'` None of the above.
#
# Enter your answer below between quotes. For example, if you wanted to answer 'a', your answer would look like: q7.answer <- 'a'.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q7.answer <- '...'
q7.answer # print your answer

# %%
. = ottr::check("tests/q7.R")

# %% [markdown]
# **Question 8.** Comparing the coefficients on the `treat` variable the bivariate regression in Question 1 to the same coefficient in the multivariate regression that includes covariates in Question 6, you can see that the coefficients change very little.
#
# Which of the following *IS* a reason that the coefficients are similar?  Or, if none of the statements are correct, choose `'e'`.
#
# - `'a'` Treatment assignment is randomized, so the empirical correlation between covariates and values of the `treat` variable should be weak.
# - `'b'` Treatment assignment is randomized, so the empirical correlation between covariates and values of the `treat` variable should be zero.
# - `'c'` The covariates are strongly related to the outcome variable, as indicated by the large *t*-values for the coefficients on the covariates.
# - `'d'` The treatment is not strongly related to the outcome variable, as indicated by the small *t*-value for the coefficient on the `treat` variable.
# - `'e'` None of the statements are correct.
#
# Enter your answer below between quotes. For example, if you wanted to answer 'a', your answer would look like: q8.answer <- 'a'.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q8.answer <- '...'
q8.answer # print your answer

# %%
. = ottr::check("tests/q8.R")

# %% [markdown]
# And that ends the practice questions in this Notebook!
#
# We'll go over these questions together at the end of class, using the version of this Notebook with the answers provided. If you have questions on any other material, please have those questions ready to ask as well, and I will answer the questions if there is time.
#
# Please note again **the material covered in this Notebook is not exhaustive**.  But it gave you an opportunity to practice in a format similar to the final.  Note that if there are any questions that are similar to the practice questions in this Notebook, you will need to read the questions carefully on the exam, since answer options might be different.
#
# In preparation for the exam, **you should study all of the lectures (.pdf slides and Notebook Lectures); do any readings you have missed; carefully review the in-class assignments and problem sets; and go over your section notes.**
#
# We may also distribute a further study guide, and **you should review the study guide prepared for the midterm.**
#
# Good luck on the exam!  It's been great working with you in the class this semester.
