# %% [markdown]
# # PS 3 Problem Set 1
#
# ## Distributed Tuesday, February 17; due Monday March 2 by 11:59 PM on Gradescope
# ## <span style="color:red">READ THIS!</span> Important Notes about Problem Sets in PS 3
#
# - Just like with your in-class assignments, the questions in this problem set will be automatically graded. Therefore, you need to answer the questions exactly as we asked them: if we ask you to compute something, write the code to compute that exact value.
# - Do *not* convert your answers from decimals to percentages. For example, if you are asked the proportion of voters in `data` who are female, simply present `mean(data$female)` as your answer. Do _not_ multiply the expression by 100 to obtain a percentage.
# - Some of the coding questions below will tell you if you have the right or wrong answer if you run your code and then run the `ottr::check` cell just below it. (The multiple choice questions do not do this.)
#     - You'll know you got a question right if it says `"All tests passed!"` afterwards.
#     - If you see an error when you run the check cell, it means you got the question wrong and should try again. The question should show a hint.
#     - If you don't see anything when you run the check cell, this means the question _doesn't tell you_ if you got the right or wrong answer.
# - **If you email your GSI a question about your code, please attach your notebook as a .pdf in your email so that your GSI can see all of your code.**  You can download the notebook as a .pdf by going to "File" $\rightarrow$ "Save and Export As" and exporting your notebook as a $\rightarrow$ pdf.
# - Do not ask your GSI or the professor to look at your answer and tell you whether it is correct. We cannot give you the answers.
# - **THIS IS A COMPLETELY INDIVIDUAL ASSIGNMENT. You can discuss the problems with your classmates, but you must do your own work and write up your own answers.**
#
# ## Do Politicians Racially Discriminate Against Constituents?
#
# In this problem set, we will explore some data from [Butler and Broockman (2011)](https://doi.org/10.1111/j.1540-5907.2011.00515.x)'s field experiment on whether state legislators racially discriminate against their constituents. (You do not need to read the study.)
#
# By the end of the problem set, not only will have reviewed some key skills that you have picked up in the course so far, you will also have replicated some of the main findings from this study!

# %% [markdown]
# Let's first load the requisite package and dataset. By doing so, we can see the structure of the data. Please run the code in the cell below.

# %%
# You *must* run this cell first. Do not change the contents of this cell.
library(testthat)
library(ottr)
bb_data <- read.csv("ps1.csv")
head(bb_data)

# %% [markdown]
# In the experiment, the researchers sent every state legislator in the United States an email. In the email, the researchers posed as a constituent inquiring about how to register to vote.
#
# The emails were identical except for the name of the sender: the researchers randomly assigned names of the sender. To determine which names to use, the researchers used data from the US Census to find first and last names that are most distinctively Black or distinctively White--that is that, if you look at people with the names, a very high percentage of them either are Black or White. Based on the US Census data, the researchers used the names DeShawn Jackson for the Black name/alias (`treat_deshawn` equal `1`) and Jake Mueller for the White name/alias (`treat_deshawn` equals `0`). (An "alias" is a fake name; DeShawn Jackson and Jake Mueller were not real people, but the researchers sent emails from email addresses that made it look like they were from people named DeShawn Jackson or Jake Mueller.)
#
# The researchers then coded whether the legislator replied to the email at all in the variable `reply_atall`.
#
# The partisanship and race of the legislators who were sent the emails are given in the variables `leg_republican` and `leg_white`.
#
# **Codebook:** Here is an overview of what the variables mean:
# - `reply_atall = 1`: legislator replied; `reply_atall = 0`: legislator did not reply
# - `treat_deshawn = 1`: email sent from DeShawn Jackson (Black alias); `treat_deshawn = 0`: email sent from Jake Mueller (White alias)
# - `leg_republican = 1`: legislator to whom email was sent is a Republican; `leg_republican = 0` legislator to whom email was sent is a Democrat
# - `leg_white = 1`: legislator to whom email was sent is White; `leg_white = 0` legislator is non-White
#
# ## Part I: Data Analysis

# %% [markdown]
# ### Republican State Legislators
#
# Let's look first at Republican state legislators and how they behave.
#
# **<span style="color:blue"> Question 1 (1 point). Create a subset of the data comprising only Republican state legislators. Save this subset as `republican_subset`.  </span>**

# %%
# Replace "NULL # YOUR CODE HERE" with your code. Hint: you can finish this question using one line of code.
republican_subset <- NULL # YOUR CODE HERE

# %%
. = ottr::check("tests/q1.R")

# %% [markdown]
# -------

# %% [markdown]
# **<span style="color:blue"> Question 2 (1 point). What is the response rate <span style="text-decoration:underline">to the Black (DeShawn) alias</span> by <span style="text-decoration:underline">Republican state legislators</span>? Print this out below. </span>**
#
# *The response rate is expressed as a proportion. Please do not convert it into a percentage. We do that for you.*

# %%
# Let's first create a further subset of the data, subsetting only to 1) Republican
# state legislators 2) who were randomly assigned to receive email from the DeShawn alias.
# Hint: Start with republican_subset and subset further based on treat_deshawn.
republican_deshawn_subset <- NULL # YOUR CODE HERE

# Now, we can find the average response rate in this subset and store it in the 
# republican_deshawn_rrate variable.
# Hint: calculate the response rate by taking the mean of the reply_atall variable.
republican_deshawn_rrate <- NULL # YOUR CODE HERE

# Let's display the solution below as a percentage.
republican_deshawn_rrate * 100

# %%
. = ottr::check("tests/q2.R")

# %% [markdown]
# -------

# %% [markdown]
# **<span style="color:blue"> Question 3 (1 point). What is the response rate <span style="text-decoration:underline">to the White (Jake) alias</span> by <span style="text-decoration:underline">Republican state legislators</span>? Save this in the variable `republican_jake_rrate` below. </span>**

# %%
# First create a further subset of the data with Republican state legislators
# (republican_subset) who are randomly assigned to the white (Jake) alias
# (based on values of the treat_deshawn variable)
republican_jake_subset <- NULL # YOUR CODE HERE

# Now, we can find the response rate and store it in the republican_jake_rrate variable
republican_jake_rrate <- NULL # YOUR CODE HERE

# Let's display the solution below as a percentage.
republican_jake_rrate * 100

# %%
. = ottr::check("tests/q3.R")

# %% [markdown]
# -------

# %% [markdown]
# **<span style="color:blue"> Question 4 (1 point). How much more (or less) likely is the email sent by the Black (DeShawn) alias to get a response from a Republican state legislator, as compared to the email from the White (Jake) alias? </span>**
#
# **Hint: you've already computed the response rates to the Black (DeShawn) and White (Jake) alias above, so you just need to do some arithmetic with the variables you've already computed.**
#
# *Note: compute the Black (DeShawn) minus the White (Jake) response rate. **Do not** do the reverse.*

# %%
# Store your answer in republican_rrate_diff
republican_rrate_diff <- NULL # YOUR CODE HERE

# Let's print the solution, in percentage points.
republican_rrate_diff * 100

# %%
. = ottr::check("tests/q4.R")

# %% [markdown]
# -------

# %% [markdown]
# **<span style="color:blue"> Question 5 (1 point). Which of the following statements provides the best description of the results so far (i.e., difference in response rates to emails from Black and White constituents by Republican state legislators).  </span>**
#
# - `a`: Given the same request / email, Republican state legislators, on average, were about 8 percentage points less likely to reply to an email from the Black alias (DeShawn) than the Jake alias (Jake).
#
# - `b`: Given the same request / email, Republican state legislators, on average, were equally likely to reply to an email from the Black alias (DeShawn) than the Jake alias (Jake).
#
# - `c`: Given the same request / email, Republican state legislators, on average, were about 8 percentage points more likely to reply to an email from the Black alias (DeShawn) than the Jake alias (Jake).
#
# - `d`: The response rate of Democratic legislators is substantially higher than the response rate of Republican legislators.
#
# ----
#
# Enter `a`, `b`, `c`, or `d` between the quotes below to answer the question. For example, to answer `a`, write `q5.answer <- 'a'`.

# %%
q5.answer <- '...'
q5.answer # Prints your answer

# %% [markdown]
# -------

# %% [markdown]
# ### Democratic State Legislators
#
# Now, let's look at state legislators who are Democrats.
#
# **<span style="color:blue"> Question 6 (1 point). What is the difference in response rate between a black alias and the white alias among _Democratic state legislators_? </span>** Store your answer in a variable called `democrat_rrate_diff` and print it.
#
# The steps to answer this question are the same as the steps for questions 1-4, but now with Democratic state legislators.
#
# *Note: compute the response rate to the black alias minus the response rate to the white alias, as in Question 4 (but this time for Democratic state legislators).*

# %%
# Store your final answer in a variable called democrat_rrate_diff. 
# You should store the intermediate objects using the names provided.

# First subset to Democratic state legislators.
democrat_subset <- NULL # YOUR CODE HERE

# Then subset to Democratic state legislators who received an email from 
# the Black (DeShawn) alias.
democrat_deshawn_subset <- NULL # YOUR CODE HERE

# Then make another subset of Democratic state legislators who received 
# an email from the White (Jake) alias.
democrat_jake_subset <- NULL # YOUR CODE HERE

# Now compute the difference in the average response rates. NOTE: you should compute the difference as 
# the response rate for the email from the Black (DeShawn) alias minus 
# the response rate for the email from the White (Jake) alias.
democrat_rrate_diff <- NULL # YOUR CODE HERE

# Let's print the difference below in percentage points.
democrat_rrate_diff * 100

# %%
. = ottr::check("tests/q6.R")

# %% [markdown]
# -------

# %% [markdown]
# **<span style="color:blue"> Question 7 (1 point). Which of the following statements provides the best description of what the number you you calculated in Question 6 means?  </span>**
#
# - `a`: Given the same request / email, Democratic state legislators, in general, are less likely to respond to a constituent request from the Black alias (DeShawn) than the White alias (Jake) by about 2.6 percentage points.
#
# - `b`: Given the same request / email, Democratic state legislators, in general, are equally likely to respond to a constituent request from the Black alias by about 2.6 percentage points.
#
# - `c`: Given the same request / email, Democratic state legislators, on average, were about 2.6 percentage points more likely to reply to an email from the Black alias (DeShawn) than the Jake alias (Jake).
#
# - `d`: The response rate of Republican legislators to an email from the Black alias (DeShawn) is substantially lower than the response rate of Democratic legislators.
#
# ----
#
# Enter `a`, `b`, `c`, or `d` between the quotes below to answer the question. For example, to answer `a`, write `q7.answer <- 'a'`.

# %%
q7.answer <- '...'
q7.answer # Prints your answer

# %% [markdown]
# -------

# %% [markdown]
# ### State Legislator Race/Ethnicity
#
# So far, it seems like we've discovered something about legislator political party and how this relates to racially discriminatory behavior. But, after we dig a little deeper, we'll learn this isn't quite the whole story.
#
# Let's go back to the main dataset (`bb_data`) and examine whether the response rates would vary between White state legislators and non-White state legislators. To understand why we might want to do this, let's first examine the racial make-up of state legislators among the two parties.
#
# **<span style="color:blue"> Question 8a (0.5 points). Using `table()`, produce a one-way table of legislator race (`leg_white`) among Democratic state legislators (using `democrat_subset`) . </span>**

# %%
leg_race_democrats <- NULL # YOUR CODE HERE
leg_race_democrats # print the result

# %%
. = ottr::check("tests/q8.R")

# %% [markdown]
# -------

# %% [markdown]
# ##### **<span style="color:blue"> Question 8b (0.5 points). Using `table()`, produce a one-way table of legislator race (`leg_white`) among Republican state legislators (using `republican_subset`). </span>**

# %%
leg_race_republicans <- NULL # YOUR CODE HERE
leg_race_republicans # print the result

# %%
. = ottr::check("tests/q8b.R")

# %% [markdown]
# We can see that there are many non-white Democratic state legislators but far fewer non-white Republican state legislators. This raises a question: are the differences we found between Democratic and Republican state legislator behavior just driven by the differences in the racial composition of the parties? To answer this, let's take a look at how White Democratic legislators behave and compare it to how non-White Democratic legislators behave.
#
# Let's first find the difference in response rates rate among white Democrats.

# %% [markdown]
# -------

# %% [markdown]
# **<span style="color:blue"> Question 9 (1 point). Find the difference in response rates to the Black alias and the White alias among _white Democratic state legislators_. Save this as `white_democrat_rrate_diff` and print it. </span>**
#
# *Note: as before, compute response to black alias minus response rate to white alias.*

# %%
# Store your answer in a variable called white_democrat_rrate_diff
# You can (but are not required) store the intermediate variables 
# using the names provided. 
white_democrat_subset <- NULL # YOUR CODE HERE
white_democrat_deshawn_subset <- NULL # YOUR CODE HERE
white_democrat_jake_subset <- NULL # YOUR CODE HERE
white_democrat_rrate_diff <- NULL # YOUR CODE HERE

# Let's print the difference below in percentage points
white_democrat_rrate_diff * 100

# %%
. = ottr::check("tests/q9.R")

# %% [markdown]
# -------

# %% [markdown]
# **<span style="color:blue"> Question 10 (1 point). Find the difference in response rates rate among non-white Democrats. Save this as `nonwhite_democrat_rrate_diff` and print it. </span>**
#
# *Note: as before, compute response to black alias minus response rate to white alias.*

# %%
# Store your answer in a variable called nonwhite_democrat_rrate_diff
# You can (but are not required) store the intermediate objects using the names provided. 
# They are listed below as a hint

nonwhite_democrat_subset <- NULL # YOUR CODE HERE
nonwhite_democrat_deshawn_subset <- NULL # YOUR CODE HERE
nonwhite_democrat_jake_subset <- NULL # YOUR CODE HERE
nonwhite_democrat_rrate_diff <- NULL # YOUR CODE HERE

# Let's print the difference below in percentage points
nonwhite_democrat_rrate_diff * 100

# %%
. = ottr::check("tests/q10.R")

# %% [markdown]
# -------
#
# ## Part II.  Concepts and Interpretation

# %% [markdown]
# **<span style="color:blue"> Question 11 (1.5 points). Think about the behavior you saw among: Republican legislators, white Democratic legislators, and non-white Democratic legislators. Suppose a person said to you: "Republican legislators discriminate, but Democratic legislators don't." What would their conclusion be missing?  </span>**
#
# Choose the answer below that is closest to correct:
#
# - `a`: The person's statement is false: we cannot tell if Republican legislators are discriminating, because we can't observe the unit causal effect.
#
# - `b`: The person's statment is false: both white and non-white Democrats discriminate, albeit in opposite directions.
#
# - `c`: The person's statement is false: white Democrats and white Republican legislators discriminate against non-white constituents at the same rate in this study.
#
# - `d`: The person's statement is false: it might be the case that white constituents tend to send their petitions to Republican legislators, i.e., there could be selection bias.
#
# ----
#
# Enter `a`, `b`, `c`, or `d` between the quotes below to answer the question. For example, to answer `a`, write `q11.answer <- 'a'`.

# %%
q11.answer <- '...'
q11.answer # Prints your answer

# %% [markdown]
# ------
#
# **<span style="color:blue"> Question 12 (2 points). Evaluate the following claim from a voter. "My state legislator is a Republican. The Butler and Broockman data we analyzed in this problem set shows that my legislator racially discriminates against non-White constituents in my district." </span>**
#
# **<span style="color:blue"> Is this true or false, and why or why not?  Select the best answer.</span>**
#
# *Hint: when answering this question, think about what we learned about potential outcomes in Weeks 4-5.*
#
# - `a`: The person's statement is true because, given the same request / email, Republican state legislators, on average, were about 8 percentage points less likely to reply to an email from the Black alias (DeShawn) than the Jake alias (Jake).
#
# - `b`: The person's statment is true because an experiment provides an unbiased estimate of average causal effects; and in this experiment, given the same request / email, Republican state legislators, on average, were about 8 percentage points less likely to reply to an email from the Black alias (DeShawn) than the Jake alias (Jake).
#
# - `c`: The person's statement is false because even though Republican state legislators _on average_ racially discriminate against non-white constituents in Butler and Broockman's study, we cannot observe the counterfactual (i.e., the other potential outcome) for any individual legislator.
#
# - `d`: The person's statement is false because we cannot directly observe the average causal effect, i.e., we cannot see all the potential outcomes under both treatment conditions..
#
# ----
#
# Enter `a`, `b`, `c`, or `d` between the quotes below to answer the question. For example, to answer `a`, write `q12.answer <- 'a'`.

# %%
q12.answer <- '...'
q12.answer # Prints your answer

# %% [markdown]
# -------

# %% [markdown]
# ### Practicing Interpretation: Interpreting A Hypothetical Scenario
#
# An IT analyst for a legislature has compiled data on how many emails every member of the legislature has sent to White and non-White constituents. The two-way table below shows the mean number of emails sent to White / non-White constituents from White / non-White constituents over a legislative session.
#
# <table>
# <thead>
#   <tr>
#     <th></th>
#     <th></th>
#     <th colspan="2">Race of Constituents</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td></td>
#     <td></td>
#     <td>White</td>
#     <td>Non-White</td>
#   </tr>
#   <tr>
#       <td rowspan="2"><b>Legislator Race</b></td>
#     <td>White</td>
#     <td>243.3</td>
#     <td>149.2</td>
#   </tr>
#   <tr>
#     <td>Non-White</td>
#     <td>183.1</td>
#     <td>203.1</td>
#   </tr>
# </tbody>
# </table>
#
# **For questions 13 and 14, choose the answer that is closest to correct, taking into account both what it says about whether the statement  true or false and and the reasoning._Only use the Table above to answer these questions, not Butler and Broockman (2011)'s data._**

# %% [markdown]
# ----
#
# **<span style="color:blue"> Question 13 (1 point). The IT analyst claims: "this table shows that White legislators on average write more messages to White constituents than they do to non-White constituents." (1 point) </span>**
#
# **<span style="color:blue"> Is this true or false, and why or why not?  Select the best answer.</span>**
#
# - `a`: The analyst's statement is true because White legislators write more replies to white constituents than non-White legislators on average (243.3>149.2).
#
# - `b`: The analyst's statment is true because White legislators write more replies to white than non-White consituents on average (243.3 > 183.1).
#
# - `c`: The analyst's statment is false because members of the legislature are not randomly assigned to have White or non-White constituents.
#
# - `d`: The analyst's statment is false because an experimental researcher cannot assign legislators to be White or non-White.
#
# ----
#
# Enter `a`, `b`, `c`, or `d` between the quotes below to answer the question. For example, to answer `a`, write `q13.answer <- 'a'`.

# %%
q13.answer <- '...'
q13.answer # Prints your answer

# %% [markdown]
# -------

# %% [markdown]
# **<span style="color:blue"> Question 14 (2 points). An activist in this state claims: "The table here shows that electing a White legislator _causes_ non-Whites to receive fewer messages from their legislators. We can conclude based on the table that non-White people are less likely to receive a message from their legislator if their district elects a White legislator." </span>**
#
# **<span style="color:blue"> Is this true or false, and why or why not?  Select the best answer.</span>**
#
# - `a`: The analyst's statement is true because White legislators write more replies to white constituents than non-White legislators on average (243.3>149.2).
#
# - `b`: The analyst's statment is true because White legislators write more replies to white than non-White consituents on average (243.3 > 183.1).
#
# - `c`: The activist's claim is false because there may be a form of omitted variable bias: legislative districts that have more non-White people are more probably likely to elect non-White legislators, and more of the constituents to whom legislators write emails will also be non-White---even if there is no discrimination.
#
# - `d`: The analyst's statment is false because there may be a form of reverse causation: non-Whites receive fewer messages from their non-White legislators (203.1) than Whites receive from their White legislators (243.3)
#
# ----
#
# Enter `a`, `b`, `c`, or `d` between the quotes below to answer the question. For example, to answer `a`, write `q14.answer <- 'a'`.

# %%
q14.answer <- '...'

# %% [markdown]
# ----
#
# # Submitting Your Notebook (please read carefully!)
#
# To submit your notebook...
#
# ### 1. Click `File` $\rightarrow$ `Save Notebook`.
#
# ### 2. Wait 5 seconds.
#
# ### 3. Select the cell at the bottom of the notebook and hit run.
#
# ### 4. Submit the .zip file you just downloaded <a href="https://www.gradescope.com/" target="_blank">on Gradescope here</a>.
#
# Notes:
#
# - **This does not seem to work on Chrome for iPad or iPhone.** If you're using an iPad or iPhone, you need to download the file using **Safari**.
# - If your web browser automatically unzips the .zip file (so you see a folder instead of a .zip file), you can just upload the .ipynb file that is inside the folder.
# - If this method is not working for you, try this: hit `File`, then `Download as`, then `Notebook (.ipynb)` and submit that.

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit.

# %%
ottr::export("ProblemSet1.ipynb", pdf = TRUE, force_save = TRUE)
