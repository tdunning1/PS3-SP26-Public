# %% [markdown]
# # POLSCI 3
#
# ## <span style="color:red">READ THIS!</span> Important Notes about Problem Sets in PS 3
#
# - Just like with your in-class assignments, the questions in this problem set will be automatically graded. Therefore, you need to answer the questions exactly as we asked them: if we ask you to compute something, write the code to compute that exact value.
# - Some of the coding questions below will tell you if you have the right or wrong answer if you run your code and then run the `ottr::check` cell just below it. (The multiple choice questions do not do this, and some of the coding questions do not.)
#     - You'll know you got a question right if it says `"All tests passed!"` afterwards.
#     - If you see an error when you run the check cell, it means you got the question wrong and should try again. The question should show a hint.
#     - If you don't see anything when you run the check cell, this means the question doesn't tell you if you got the right or wrong answer.
# - **IF YOU EMAIL YOUR GSI A QUESTION ABOUT YOUR CODE, PLEASE ATTACH YOUR NOTEBOOK AS A .PDF IN YOUR EMAIL TO YOUR GSI SO THAT YOUR GSI CAN SEE ALL OF YOUR CODE. YOU CAN DOWNLOAD THE NOTEBOOK AS A .PDF BY GOING TO FILE $\rightarrow$ DOWNLOAD AS $\rightarrow$ PDF.**
# - Do not ask your GSI or the professor to look at your answer and tell you whether it is correct. We cannot give you the answers.

# %% [markdown]
# # Problem Set 3: Partisanship and party incumbency advantage
#
# In this problem set, you will explore substantive questions about the effects of partisanship and party incumbency advantage.
#
# In Part 1, you will analyze an experiment. This will give you a chance to review and practice some R tools we saw before the midterm and also think conceptually about the findings.
#
# In Part 2, you will use data from Lee's (2008) regression-discontinuity design that we discussed in class in Week 9 to analyze the effects of party incumbency.
#
# ### Part 1. Does Party "Trump" Ideology?
#
# In the first part of this problem set, we explore a long-standing question in American politics.
#
# Are people Republicans because they are conservatives and Democrats because they are liberals? That is, do their political ideologies dictate which party they choose to be a member of?
#
# Or is it the reverse? Instead, are people conservative because they are Republicans and liberals because they are Democrats? That is, do their partisan loyalties come first and cause them to adopt the political ideologies of their party?
#
# This is the exact question [Barber and Pope (2018)](https://doi.org/10.1017/S0003055418000795) studied. We'll analyze data from their study in this problem set.
#
# Let's first load the requisite packages and dataset. Please run the code in the cell below.

# %% [markdown]
# ### About the Study
#
# In the study, the researchers fielded a survey through YouGov, an online survey firm. On YouGov's website, it states:
# > For each survey, a representative sample of 1,500 respondents is selected from YouGov’s U.S. research panel. Panelists are invited to each survey, based upon their age, gender, race, and education, in proportion to their frequency to the frequency of adult citizens in the most recent American Community Survey.
#
# (The American Community Survey is a rigorous measurement of characteristics of the US population from the US Census.)
#
# The survey asked respondents whether they agreed with ten liberal positions (the `support` variable) on ten different issues. Each row in this dataset is one person's response to one of the questions.
#
# There was also an experiment at this point, which we'll describe in more detail later in this problem set.
#
# After recording the respondents' positions on each issue, the researchers ask respondents about their gender (`male`), race (`white`), age (`age`), their approval of Trump on a 5-point scale (`trump_approve`) and their party identification (`party`).
#
# Let's take a look at the data:

# %%
# You *must* run this cell, do not change its contents.
library(testthat)
library(ggplot2)
library(estimatr)
bp_data <- read.csv("ps3.csv")

# Let's look at the structure of the data
head(bp_data)

# %% [markdown]
# To recap, here are what the variables mean:
# - `question`: the issue question asked
# - `support`: equals `1` if the respondent supported the liberal position on the issue; `0` if the respondent opposes the liberal position (i.e., has the conservative position); equals `NA` (i.e., missing data) if the respondent said 'don't know' (we can ignore the 'don't know' cases for the purposes of the problem set)
# - `race_white`: equals `1` if the respondent is white; equals `0` if the respondent is non-white
# - `age`: the respondent's age in years
# - `high.income`: equals `1` if the respondent has a high income (above \$100,000 per year); equals `0` otherwise
# - `trump_approve`: the respondent's approval of Trump, from 1 (strongly disapprove) to 5 (strongly approve)
# - `party`: what political party the respondent said they identified with; equal to `"democrat"`, `"republican"`, or `"independent"`
# - `treat`: either `"control"` if only asked their own opinion or `"libtrump"` if the question also mentioned that Donald Trump had the liberal position on the policy (this is explained in more detail below)
# - `weight`: the survey weight

# %% [markdown]
# -----
#
# ###  Analyzing the experiment
#
# As mentioned above, the authors were interested in whether our issue views cause us to pick our political loyalties (to parties or politicians) or, rather, if our political loyalties (to parties and politicians) cause our issue views. To examine this big question, the authors decided to investigate whether telling people about Donald Trump's positions on the issues on the survey would change survey respondent's own stated views on these issues.
#
# The authors thought that Donald Trump represented a unique opportunity to examine these questions because Trump had previously expressed both liberal and conservative positions on all ten issues at various times. It's not common that Republican politicians express liberal views on issues, so they took this unique opportunity to see how both Democrats and Republicans would react to (accurate!) information about the liberal positions on these issues that Trump had espoused (at one point in time).
#
# To do this, the respondents to this survey were randomly assigned to various treatment conditions. For this assignment, we will focus only (and you only have data on) the following 2 treatment conditions:
#
# - Control group (`treat` equals `"control"`): respondents were asked of whether they support or oppose the liberal position
# - Liberal Trump group (`treat` equals `"libtrump"`): respondents were first told that Donald Trump *supports* the liberal position, then the respondents were asked of whether they support or oppose the liberal position
#
# Let's take the example of the question on the minimum wage. Those in the control group would see the following version of the minimum wage question:
#
# ![](self.png)
#
# But those randomly assigned to the "liberal Trump" group would see the following:
#
# ![](liberal_trump.png)
#
# As seen above, the liberal Trump group simply includes the additional sentence "Donald Trump has said that he supports the policy."
#
# Note that the respondents were in the same treatment condition for *all* of the 10 questions. For example, if a respondent was shown the liberal Trump position for the minimum wage in the question text, she would also see the liberal Trump position for the Iran Nuclear Deal in the question text as well.
#
# As a reminder, here's what the treatment variable looks like:

# %%
# RUN THIS CELL
table(bp_data$treat)

# %% [markdown]
# ------
#
# **Question 1. Looking at the entire sample, use `difference_in_means()` to estimate the treatment effect of receiving the liberal Trump treatment (relative to the control) on stating support for liberal policies (`support`)? Save your output to `treat_effect_avg`.** (1 point)
#
# For this first question only, you will be able to check your answer to see that you got it right using the Ottr cell

# %%
# Replace `NULL # YOUR CODE HERE` with your answer. 
# Hint: You can finish this question with one line of code
trump_effect_avg <- NULL # YOUR CODE HERE

# Now, let's see what is in trump_effect_avg
trump_effect_avg

# %%
. = ottr::check("tests/q1.R")

# %% [markdown]
# ------
#
# Next, let's see how this effect varies by whether people identify as Democrats or Republicans.
#
# As a reminder, this is the `party` variable:

# %%
# RUN THIS CELL
table(bp_data$party)

# %% [markdown]
# ------
#
# **Question 2. Looking at _just Republicans_ (so `party` equals `'republican'`), use `difference_in_means()` to estimate the treatment effect of receiving the liberal Trump treatment (relative to the control) on stating support for liberal policies (`support`)? Save your output to `trump_effect_reps`.**

# %%
# First produce a subset of the data with only Republicans 
reps_only <- NULL # YOUR CODE HERE

# Now, estimate the treatment effect among Republican respondents
trump_effect_reps <- NULL # YOUR CODE HERE

# Now, let's see what is in treat_effect_reps
trump_effect_reps

# %% [markdown]
# -------
#
# **Question 3. Looking at _just Democrats_ (so `party` equals `'democrat'`), use `difference_in_means()` to estimate the treatment effect of receiving the liberal Trump treatment (relative to the control) on stating support for liberal policies (`support`)? Save your output to `trump_effect_dem`.** (1 point)

# %%
# Replace "NULL # YOUR CODE HERE" with your code. First produce a subset of the data with only Democrats 
dems_only <- NULL # YOUR CODE HERE

# Let's find the treatment effect among Democrat respondents
trump_effect_dem <- NULL # YOUR CODE HERE

# Now, let's see what is in trump_effect_dem
trump_effect_dem

# %% [markdown]
# -------------
#
# **Question 4. `TRUE` or `FALSE`: Based on the results in Questions 2 and 3, the treatment effect of the liberal Trump treatment is larger among Republican respondents than Democrat respondents.** (1 point)
#
# Save your answer in `q4.answer`. Do not use quotes. For example, to answer `TRUE`, type `q4.answer <- TRUE`.

# %%
q4.answer <- NULL # YOUR CODE HERE

q4.answer # print your answer

# %% [markdown]
# -----
#
# **Question 5. `TRUE` or `FALSE`: The results in Questions 3 and 4 indicate that being Republican _causes_ people to have a larger treatment effect from the liberal Trump prime. That is, if the Democrats in the study decided to become Republicans, they would start to react in a similar way to the liberal Trump treatment.** (1 point)
#
# Save your answer in `q5.answer`. Do not use quotes. For example, to answer `TRUE`, type `q5.answer <- TRUE`.

# %%
q5.answer <- NULL # YOUR CODE HERE

q5.answer # print your answer

# %% [markdown]
# ------
#
# **Question 6 (1 point).** Which of the following interpretations of the findings is **NOT** supported by the evidence in this study?
#
# - `'a'` The study shows that when people learn that a President of their party supports a policy, they are more likely to support it.
# - `'b'` It is possible that the findings might not generalize outside of the context of the study: for example, results might be different for politicians other than Trump, or voters might be behaving differently during the Trump era.
# - `'c'` We cannot reject the null hypothesis that the Trump treatment had no effect on Democrats.
# - `'d'` Although they appear different, we cannot reject the null hypothesis that the effects for Democrats and Republicans are the same.
#
# Enter your answer between quotes. For example, if you wanted to answer `'a'`, you would type `q6.answer <- 'a'`.

# %%
q6.answer <- '...'
q6.answer # print your answer

# %% [markdown]
# ----
#
# ### Descriptive Analyses
#
# Let's next perform some descriptive analysis using the survey questions in dataset. For this second set of questions, we'll ignore the experiment and just look at the relationship between people's background and whether they have liberal opinions on these issues.
#
# In the analysis in the next code cell, you'll run the `difference_in_means()` function to assess whether those with high incomes have different political opinions. In particular, you will use `difference_in_means()` to obtain the difference in support for liberal policies (`support`) between people where `high.income` equals 1 and 0. The result will be stored in `diff_opinions`.
#
# Note: the code "weights" the analysis using the `weight` variable -- this accounts for some features of the survey design. We have not discussed weighting so far in this class, but the weight variable helps us estimate descriptive relationships in the population accurately.

# %%
# RUN THIS CELL

diff_opinions <- difference_in_means(support ~ high.income, data = bp_data, weight = weight) 

# Now, let's see what is in diff_opinions
diff_opinions

# %% [markdown]
# -----
#
# **Question 7a (0.5 points)**. `TRUE` or `FALSE`: Based on the output in  `diff_opinions` above, our best guess is that people with high incomes are more politically liberal than people with lower incomes.
#
# Save your answer in `q7a.answer`. Do not use quotes. For example, to answer `TRUE`, type `q7a.answer <- TRUE`.
#
# _Note: this question will not tell you whether you got the right answer or not._

# %%
q7a.answer <- NULL # YOUR CODE HERE

q7a.answer # print your answer

# %% [markdown]
# -----
#
# **Question 7b (0.5 points).** `TRUE` or `FALSE`: The results stored in `diff_opinions` indicate the following: "earning more money *causes* people to have different political opinions on the 10 issues asked about on this survey."
#
# Save your answer in `q7b.answer`. Do not use quotes. For example, to answer `TRUE`, type `q7b.answer <- TRUE`.
#
# _Note: this question will not tell you whether you got the right answer or not._

# %%
q7b.answer <- NULL # YOUR CODE HERE

q7b.answer # prints your answer

# %% [markdown]
# -----
#
# **Question 8 (1 point).** Which of the following is **NOT** a correct justification for the correct answer in question 7b?
#
# - `'a'` The evidence suggests that people who earn more money are on average less liberal, but this result provides evidence for a descriptive--not causal--relationship.
# - `'b'` There could be omitted variable bias: for example, family background (e.g. the profession and views of one's parents) could be related both to earning more money and to one's political opinions.
# - `''c'` Richer people often want to protect their wealth and income from taxation, which makes them more politically conservative.
# - `'d'` Confounding means that it may be difficult to separate the effect of the treatment from the effect of the confounders.
#
# Enter your answer between quotes. For example, if you wanted to answer `'a'`, you would type `q8.answer <- 'a'`.

# %%
q8.answer <- '...'
q8.answer # print your answer

# %% [markdown]
# ### Part 2. What is the effect of party incumbency?
#
# In this second part of the problem set, you will analyze data from the Lee (2008) study of incumbency advantage that we discussed in the in-class lecture in Week 9.
#
# In this study, Lee (2008) used a "close election design" -- a prevalent example of a discontinuity design.
#
# Let's read in the data:

# %%
# RUN THIS CELL, do not change its contents
library(rdrobust)

lee <- read.csv("lee.csv")
head(lee)

# %% [markdown]
# There are only few variables shown here (we've extracted these from the larger Lee (2008) replication data set).  Here is what they mean:
#
# - `'X'` this is an identifier for the U.S. Congressional district (each row of the dataset is a district);
# - `'yearel'` is the year of the Congressional election;
# - `difdemshare` is the difference in the Democratic party's vote share in the election at time *t*---i.e., in the close election that assigned Democrats to be either the incumbents (the election winners) or the opposition party (the eleciton losers) in the next election.
# - `mdemsharenext` is the difference in the Democratic party's vote share in the election at time *t+1*---i.e., in election that followed the close election that assigns Democrats to be incumbents or the opposition party.
# - `mdemshareprev` is the the difference in the Democratic party's vote share in the election at time *t-1*---i.e., in election that preceded the close election that assigns Democrats to be incumbents or the opposition party.
#
# Before you analyze the data, answer a few conceptual questions:

# %% [markdown]
# **Question 9 (1 points)**  Which is the running (a.k.a. forcing or assignment) variable in this study?
#
# - `'a'` `difdemshare`;
# - `'b'` `mdemsharenext`;
# - `'c'` `mdemshareprev`; or
# - `'d'` It is impossible to tell with the information provided.
#
# Enter your answer between quotes. For example, if you wanted to answer `'a'`, you would type `q9.answer <- 'a'`.

# %%
q9.answer <- '...'
q9.answer # print your answer

# %% [markdown]
# **Question 10 (1 points)**  Which is the outcome variable in this study?
#
# - `'a'` `difdemshare`;
# - `'b'` `mdemsharenext`;
# - `'c'` `mdemshareprev`; or
# - `'d'` It is impossible to tell with the information provided.
#
# Enter your answer between quotes. For example, if you wanted to answer `'a'`, you would type `q10.answer <- 'a'`.

# %%
q10.answer <- '...'
q10.answer # print your answer

# %% [markdown]
# **Question 11 (1 points)**  Which is a pre-treatment covariate in this study?
#
# - `'a'` `difdemshare`;
# - `'b'` `mdemsharenext`;
# - `'c'` `mdemshareprev`; or
# - `'d'` It is impossible to tell with the information provided.
#
# Enter your answer between quotes. For example, if you wanted to answer `'a'`, you would type `q11.answer <- 'a'`.

# %%
q11.answer <- '...'
q11.answer # print your answer

# %% [markdown]
# **Question 12 (1 points)**  What is the value of the running variable at which the treatment (Democratic party incumbency) switches on or off in this study?
#
# - `'a'` 0;
# - `'b'` 40,500;
# - `'c'` 5000; or
# - `'d'` at a bandwidth of plus or minus 5%.
#
# Enter your answer between quotes. For example, if you wanted to answer `'a'`, you would type `q12.answer <- 'a'`.

# %%
q12.answer <- '...'
q12.answer # print your answer

# %% [markdown]
# Now, let's analyze the data from this discontinuity design.
#
# **Question 13 (1 point)** Use `rdplot()` to create the type of figure that we looked at for several discontinuity designs in Week 9, including for Lee's study. The outcome variable in this study should be on the vertical (y) axis; the running variable should be on the x-axis.
#
# *Hints* Review Week 9 Notebook Lecture or the R Cheat Sheet for the syntax for `rdplot()`.
#
# You will be able to check your answer for this question using the Otter cell.

# %%
# be sure to run the cell after entering your code
# Don't worry here about the additional output printed along with your plot

lee_outcome_plot <- NULL # YOUR CODE HERE

# %%
. = ottr::check("tests/q13.R")

# %% [markdown]
# **Question 14 (1 point)** Now, use `rdplot()` to create a similar figure as in Question 13, but now with the pre-treatment covariate on the vertical (y) axis. The running variable should be on the x-axis.
#
# *Hints* Review Week 9 Notebook Lecture or the R Cheat Sheet for the syntax for `rdplot()`.

# %%
# be sure to run the cell after entering your code
# Don't worry here about the additional output printed along with your plot

lee_covariate_plot <- NULL # YOUR CODE HERE

# %% [markdown]
# **Question 15 (1 point)**. Which of the following is **NOT** an interpretation consistent with the correct analysis of these data using `rdplot()` in Questions 13 and 14?
#
# - `'a'` There is clear visual evidence of a discontinuity in the outcome variable at the threshold determining treatment assignment---suggesting a causal effect of incumbency on the incumbent's vote share margin in the next election.
# - `'b'`  There is no clear visual evidence of a discontinuity in the lagged outcome variable at the threshold determining treatment assignment--suggesting no causal "effect" of incumbency on the lagged outcome variable.
# - `'c'` There is clear visual evidence of a discontinuity in the incumbent's vote share in the next election at time t+1---suggesting that the placebo test is "passed" in this case.
# - `'d'` There is no clear visual evidence of a discontinuity in the pre-treatment covariate at the threshold determining treatment assignment---suggesting that the placebo test is "passed" in this case.
#
# Enter your answer between quotes. For example, if you wanted to answer `'a'`, you would type `q15.answer <- 'a'`.

# %%
q15.answer <- '...'
q15.answer # print your result

# %% [markdown]
# **Question 16 (1 point)**. Which of the following is **NOT** a correct statement, consistent with results of the analysis using `rdplot()` in Questions 13 and 14?
#
# - `'a'` There is clear visual evidence of a difference in the average outcomes just on either side of the key threshold or cutoff value of the running variable.
# - `'b'` There is an apparent upward-sloping relationship between the outcome variable and the running variable; thus, we may want to estimate the effect of the treatment as a difference of intercepts at the cutoff, rather than a difference of means.
# - `'c'` Using `difference_in_means() in this study may conflate any real treatment effect with a difference in average outcomes that is due simply to the upward-sloping relationship between the outcome and running variables.
# - `'d'` The upward-sloping relationship between the outcome and running variables means we cannot run a useful "placebo test" in this study.
#
# Enter your answer between quotes. For example, if you wanted to answer `'a'`, you would type `q16.answer <- 'a'`.

# %%
q16.answer <- '...'
q16.answer #print your answer

# %% [markdown]
# ----
#
# # Submitting Your Notebook (please read carefully!)
#
# To submit your notebook...
#
# ### 1. Click `File` $\rightarrow$ `Save and Checkpoint`.
#
# ### 2. Wait 5 seconds.
#
# ### 3. Select the cell below and hit run.

# %%
ottr::export("ProblemSet3.ipynb")

# %% [markdown]
# After you hit "Run" on the cell above, click the download link. A .zip file should download to your computer.
#
# (If you make changes to your notebook, you'll need to hit save and then run the cell above again before you submit to get a new version of it.)
#
# ### 4. Submit the .zip file you just downloaded <a href="https://www.gradescope.com/" target="_blank">on Gradescope here</a>.
#
# Notes:
#
# - **This does not seem to work on Chrome for iPad or iPhone.** If you're using an iPad or iPhone, you need to download the file using **Safari**.
# - If your web browser automatically unzips the .zip file (so you see a folder instead of a .zip file), you can just upload the .ipynb file that is inside the folder.
# - If this method is not working for you, try the "old way": hit `File`, then `Download as`, then `Notebook (.ipynb)` and submit that.
