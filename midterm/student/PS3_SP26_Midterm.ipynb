# %% [markdown]
# # POLSCI 3 -- Midterm Exam
#
# There are 23 questions on this exam and 23 points possible. (20 of the questions are worth one point each; question 14 has two parts, worth one point each, and questions 18 and 21 are worth 0.5 points each).
#
# You might need to think a bit about some of the questions---but if you have studied the material, I feel confident you can answer them!!!
#
# For multiple-choice questions in both Parts 1 and 2,
# - Remember to use process of elimination if needed to find the answer!
# - Also, pay attention to whether the question is asking for the option that IS correct or is NOT correct!
#
# In Part 2, you will also analyze data from an experiment.  You can check your answer using the otter cell for the first data analysis question (but not after that).
#
# Procedures and rules for the exam:
# - You are required to be present in the classroom to receive any credit for the exam.  If you have already let us know about an excused absence, we have taken this into account.  If you are sick and will receive a medical excuse for an absence, you should let your GSI know as soon as possible.
# - When you arrive, the GSIs will direct you to a row of the classroom to sit in.  **To the extent possible, please distribute yourselves so you don’t have another student on either side of you, though that won’t be possible for everyone.**
# - You may use all class materials, including readings, the in-class lectures, the Notebook Lectures, and the R Cheat Sheet, as well as any notes you have prepared.  Your notes can be in digital form (using Google Docs, a word processor, or another digital format including those that require Internet access).
# - However, you may not use any AI-assisted features in any software to help you on the exam, including AI answers to conceptual or coding questions. You also may not use a general internet search to search for answers to questions.
# - **Failure to respect the prohibitions on AI and general Internet searchs, or any form of cheating or academic dishonesty, will be punished in accordance with class and university policies and may result in a failing grade on the exam.**

# %% [markdown]
# ## Part I. Conceptual questions.
#
# The first part of this midterm asks multiple-choice conceptual questions drawn about material we have covered so far in the course (up to and including Week 8).

# %% [markdown]
# **Question 1 (1 point)**. Which of the following is **NOT** a correct way to complete the following sentence?  "The coefficient of correlation between two variables...
#
# - `'a'` ...is not necessarily a measure of causation."
# - `'b'` ...is often a good way to summarize the linear association between the variables."
# - `'c'` ...is usually insensitive to the presence of outliers."
# - `'d'` ...is usually insensitive to nonlinear associations."
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q1.answer <- 'a'`.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q1.answer <- '...'
q1.answer # print your answer

# %% [markdown]
# **Question 2 (1 point)**. Which of the following is **NOT** a correct way to complete the following sentence?  "A histogram...
#
# - `'a'` ...can be used to represent chances."
# - `'b'` ...shows the association between two variables."
# - `'c'` ...is analogous to a one-way table but is used for continuous variables, or those with many categories."
# - `'d'` ...shows the frequency of cases (units) that fall into different bins."
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q1.answer <- 'a'`.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q2.answer <- '...'
q2.answer # print your answer

# %% [markdown]
# **Question 3 (1 point)**. Which of the following is **NOT** a correct way to complete the following sentence?  "If the value of a standardized variable for a given observation is 3.0, it means...
#
# - `'a'` ...the observation's value is above average."
# - `'b'` ...the observation's value is greater than at least 90% of the other observations, if the variable is normally distributed."
# - `'c'` ...the observation's value is 3.0 standard deviations away from the average."
# - `'d'` ...the observation's unstandardized value cannot be negative."
#
# *Hints*: An "observation" is a case or unit in a dataset; when a variable is standardized, it is put into standard units.
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q3.answer <- 'a'`.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q3.answer <- '...'
q3.answer # print your answer

# %% [markdown]
# **Question 4 (1 point)**. Which of the following is **NOT** a correct way to complete the following sentence?  "The potential outcomes framework..."
#
# - `'a'` ...embeds ideas of counterfactuals and of units' responses to interventions."
# - `'b'` ...can illustrate the fundamental problem of causal inference."
# - `'c'` ...helps us to estimate the unit causal effect, using the logic of random sampling from an experimental population (the box)."
# - `'d'` ...helps to clarify what parameter we estimate when we use difference_in_means() to analyze an experiment in R."
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q4.answer <- 'a'`.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q4.answer <- '...'
q4.answer # print your answer

# %% [markdown]
# **Question 5 (1 point)**. Which of the following is **NOT** a correct way to complete the following sentence?  "Selection bias..."
#
# - `'a'` ...is a characteristic of experiments."
# - `'b'` ...means that treatment assignment depends on units' potential outcomes."
# - `'c'` ...does not exist in a study where units are randomly assigned to treatments."
# - `'d'` ...is a characteristic of many observational studies."
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q5.answer <- 'a'`.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q5.answer <- '...'
q5.answer # print your answer

# %% [markdown]
# **Question 6 (1 point)**. Which of the following **IS** a correct way to complete the following sentence?  "Random assignment in an experiment...
#
# - `'a'` ...guarantees that the treatment group and the control group are equivalent on background characteristics."
# - `'b'` ...implies that the treatment group is a simple random sample from the study group."
# - `'c'` ...minimizes noise in estimators of the average treatment effect."
# - `'d'` ...ensures that the experimental procedure cannot be replicated, because of chance error."
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q6.answer <- 'a'`.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q6.answer <- '...'
q6.answer # print your answer

# %% [markdown]
# **Question 7 (1 point)**. Which of the following is **NOT** a correct way to complete the following sentence?  "The standard error in an experiment...
#
# - `'a'` ...is the standard deviation of the sampling distribution of the difference-in-means estimator."
# - `'b'` ...decreases when the size of the treatment and control groups increase."
# - `'c'` ...follows the square root law, so it approximately doubles when you cut the size of the treatment and control groups in half."
# - `'d'` ...is larger when the standard deviation of the outcome variable is greater."
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q7.answer <- 'a'`.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q7.answer <- '...'
q7.answer # print your answer

# %% [markdown]
# **Question 8 (1 point)**. Which of the following is **NOT** a correct way to complete the following sentence?  "The t-statistic in an experiment...
#
# - `'a'` ...is the estimate divided by the standard error."
# - `'b'` ...conventionally leads us to reject the null hypothesis when it is greater than 1.96 or less than -1.96."
# - `'c'` ...is an important parameter for deciding if the true effect is statistically significant."
# - `'d'` ...helps us to calculate the $p$-value."
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q8.answer <- 'a'`.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q8.answer <- '...'
q8.answer # print your answer

# %% [markdown]
# **Question 9 (1 point)**. Which of the following **IS** a correct way to complete the following sentence? "The p-value in an experiment...
#
# - `'a'` ...tells us how likely it is that the null hypothesis is true."
# - `'b'` ...tells us how likely it is that we would reject the null hypothesis if the null hypothesis is false."
# - `'c'` ...tells us how likely it is that the estimate would occur by chance if the null hypothesis is false."
# - `'d'` ...tells us how likely it is that the estimate would occur by chance if the null hypothesis is true."
#
# Enter your answer below between quotes. For example, if you wanted to answer 'a', your answer would look like: q9.answer <- 'a'.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q9.answer <- '...'
q9.answer # print your answer

# %% [markdown]
# **Question 10 (1 point)**. Which of the following **IS** a correct way to complete the following sentence? "The 95% confidence interval in an experiment...
#
# - `'a'` ...tells us that the true effect has a 95% probability of being contained in the interval."
# - `'b'` ...contains the true effect 95% of the time it is constructed."
# - `'c'` ...tells us the range of plausible estimates but only if the null hypothesis is true."
# - `'d'` ...tells us the range of plausible estimates but only if the null hypothesis is false."
#
# Enter your answer below between quotes. For example, if you wanted to answer 'a', your answer would look like: q9.answer <- 'a'.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q10.answer <- '...'
q10.answer # print your answer

# %% [markdown]
# **Question 11 (1 point)**. Draws are being made at random with replacement from a box.  The number of draws is getting larger and larger.  Which of the following statements is **NOT** correct?
#
# - `'a'` The probability histogram for the sum of the draws (when put in standard units) gets closer and closer to the standard normal curve.
#
# - `'b'` The histogram for the numbers in the box (when put in standard units) gets closer and closer to the standard normal curve.
#
# - `'c'` The standard deviation of the probability histogram for the average of the draws gets smaller and smaller.
#
# - `'d'` The standard error of the average of the draws gets smaller and smaller.
#
# Enter your answer below between quotes. For example, if you wanted to answer 'a', your answer would look like: q11.answer <- 'a'.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q11.answer <- '...'
q11.answer # print your answer

# %% [markdown]
# ## Part II. Data analysis and interpretation
#
# Now, you'll use data from a study by <a href="https://www.journals.uchicago.edu/doi/pdf/10.1086/714923" target="_blank">Grose et al.</a> on social lobbying.  For reference, you can find the paper <a href="https://www.journals.uchicago.edu/doi/pdf/10.1086/714923" target="_blank">here</a>, though you don't need to read or look at it to complete the midterm exam.
#
# In this study, the authors worked with a lobbying firm that was lobbying the California state legislature on behalf of an education organization to increase education spending in the state. The authors did an experiment to test their theory that what they call *social lobbying*---taking a legislator to a social location such as a bar or restaurant---is more effective than lobbying legislators in their offices. To test this, they randomly assigned legislators to three groups:
# - a control group that wasn't lobbied
# - a social lobbying group that was asked to go to a restaurant or bar and talk about the bill
# - an office lobbying group that was asked to talk about the bill in their offices
#
# The study consisted of 119 legislators (there are 120 state legislators in California, but there was a vacancy at the time the study was conducted).
#
# Let's first read in the data so that you can answer some questions about it.

# %% [markdown]
# ### Importing the Data

# %% [markdown]
# Run the cell below to import the packages we need and then save the dataset from the social lobbying study into a dataset called `data`.

# %%
#RUN THIS CELL
library(testthat)
library(estimatr)

data <- read.csv('ps3_lobbying.csv')
head(data)

# %% [markdown]
# Here is what each column means:
#
# - `caseid`: Number indicating each legislator/district (Total 120)
# - `supportgroup`: This is the *outcome*. It is a measure of whether the legislator agreed to list their name publicly as a "sponsor" of the bill.
# - `treat`: This is the *treatment*. It has several possible values:
#     - `"control"`: the office received no contact from the lobbyist
#     - `"officelobby"`: the legislator was asked to meet to discuss the bill in their office
#     - `"sociallobby"`: the legislator was asked to meet to discuss the bill at a social location (a restaurant or bar)
# - `ally`: The authors thought that social lobbying might be especially effective among legislators who had supported the group's priorities in the past. To measure this, they asked the lobbyist: "In your opinion, how well does the phrase ‘ally of the interest group’ describe the legislator?" This is therefore the lobbyists' rating of whether the legislator is an ally of the interest group (values 0, 1/3, 2/3, and 1).
# - `female` : legislator gender, 1 = legislator is female; 0 = not
#
# Here is what the `treat` variable looks like:

# %%
# RUN THIS CELL
table(data$treat)

# %% [markdown]
# ## Conceptual questions about the study
#
# First, please answer two conceptual questions in the context of this study.

# %% [markdown]
# **Question 12 (1 point)**. Which of the following is **NOT** a true statement:
#
# - `'a'` The true average causal effect is the average of the unit causal effects for 119 legislators.
# - `'b'` The fundamental problem of causal inference means we cannot observe the unit causal effect; we can only observe the true average causal effect.
# - `'c'` The average of the `support group` variable when `treat` is equal to `"sociallobby"`, minus the average of the `support group` variable when `treat` is equal to `"control"`, is an estimate of the average causal effect of the social lobby treatment.
# - `'d'` For the 38 legislators assigned to the `"control"` condition, we can observe the potential outcomes under control.
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q1.answer <- 'a'`.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q12.answer <- '...'
q12.answer # print your answer

# %% [markdown]
# **Question 13 (1 point)**. Which of the following is **NOT** a true statement:
#
# - `'a'` The 38 legislators assigned to the control group are a random sample of the population of 119 legislators.
# - `'b'` The average of the outcome variable of legislators in the `"officelobby"` group provides an unbiased estimator of the potential outcome under assignment to the `"officelobby"` treatment.
# - `'c'` The difference between the average in the `"officelobby"` group and the average in the `"control"` group is the true average effect of the `"officelobby"` treatment.
# - `'d'` If we (hypothetically) were to conduct this experiment a very large number of times and calculate the difference between the average of the outcome in the `"sociallobby"` and the `"control"` groups in each experiment, the standard deviation of the differences of means would approximate the standard error of the difference-of-means estimator.
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q2.answer <- 'a'`.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q13.answer <- '...'
q13.answer # print your answer

# %% [markdown]
# -----
#
# ### Data Analysis + Interpretation
#
# Now, let's do some analysis and interpretation of the data.

# %% [markdown]
# **Question 14a (1 point).** Use the `difference_in_means()` function to estimate the effect of the *office lobbying* treatment, relative to the control group. Store the results in `office.effect`.
#
# **For this question only**, you will be able to check your answer using the otter cell following the question -- if you do not get the answer correct, try again!

# %%
#Estimate the treatment effect using difference_in_means()
office.effect <- NULL # YOUR CODE HERE
office.effect # print your result

# %%
. = ottr::check("tests/q14a.R")

# %% [markdown]
# **Question 14b (1 point).** Use the `difference_in_means()` function to estimate the effect of the *social lobbying* treatment, relative to the control group. Store the results in `social.effect`.

# %%
#Estimate the treatment effect using difference_in_means()

social.effect <- NULL # YOUR CODE HERE
social.effect

# %% [markdown]
# -------------------------------------------------------------------------------

# %% [markdown]
# **Question 15 (1 point).** Can you identify which part of the output above contains the standard error? Copy down at least the first 5 digits of the standard error from `office.effect` in Question 14a and store it in `std.error`. You can copy and paste the entire standard error (that is, all the digits) if you want.

# %%
# Copy down the first 5 digits below.
std.error <- NULL # YOUR CODE HERE
std.error

# %% [markdown]
# -------------------------------------------------------------------------------

# %% [markdown]
# **Question 16 (1 point).** Thinking about the standard error of this study, which of the following is **NOT** correct?
#
# - `a`: This standard error helps measure how much we'd expect the estimate from the experiment to differ from the truth (the real effect) by chance.
# - `b`: All else equal, if the sample size of (that is, number of observations in) this study were larger, the standard error would be smaller.
# - `c`: This standard error helps measure how biased the experiment is. If the experiment had no bias, the standard error would be zero.
# - `d`: The fact that the estimate is small relative to the standard error indicates that we can't be very confident the true effect of this treatment is different from zero.
#
# Replace the `'...'` below with the right answer. For example, to answer `'a'`, your code below would be `q3.answer <- 'a'`.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q16.answer <- '...'
q16.answer # print your answer

# %% [markdown]
# -------
#
# **Question 17 (1 point).** Suppose we were to double the `supportgroup` outcome so that it had values of 0 and 2 instead of 0 and 1. This would double both the standard deviation of the variable and the estimated effect. Based on the formulas for the standard error and the t-statistic (hint: see Week 6, Notebook Lecture 1), which of the following most accurately describes what would happen?
#
# - `a`: The standard error stays the same, and the t-statistic stays the same
# - `b`: The standard error increases, and the t-statistic stays the same
# - `c`: The standard error stays the same, and the t-statistic increases
# - `d`: The standard error increases, and the t-statistic increases
#
# Replace the `'...'` below with the right answer. For example, to answer `'a'`, your code below would be `q7.answer <- 'a'`.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q17.answer <- '...'
q17.answer # print your answer

# %% [markdown]
# -------------------------------------------------------------------------------

# %% [markdown]
# **Question 18 (0.5 points).** You found that the estimated effect of the office lobbying treatment is:

# %%
# RUN THIS CELL

office.effect$coefficient

# %% [markdown]
# And you found that the standard error is:

# %%
# RUN THIS CELL

std.error

# %% [markdown]
# A lobbyist who hasn't taken this class sees that the estimated effect of office lobbying in this experiment is negative. She asks you how she should interpret the data. Does the fact that there is a negative estimated effect in the experiment mean that the experiment **demonstrates for sure** that the office lobbying done in this study was actually counterproductive?
#
# *Hint: Replace the `...` below with `TRUE` if you think this experiment demonstrates that the office lobbying it studied was counterproductive and `FALSE` if you think it does not demonstrate that.*

# %%
experiment.demonstrates.office.lobbying.reduced.bill.support <- NULL # YOUR CODE HERE

experiment.demonstrates.office.lobbying.reduced.bill.support # Print your answer

# %% [markdown]
# -------------
#
# The researchers who did this experiment wanted to argue that social lobbying is more effective than office-based lobbying. Let's see what the experiment says about this.
#
# **Question 19 (1 point).** Use the `difference_in_means` function to estimate the effect of social lobbying **relative to office-based lobbying**. Make the legislators assigned to social lobbying the treatment group and the legislators assigned to office lobbying the baseline group.

# %%
social.vs.office <- NULL # YOUR CODE HERE
social.vs.office

# %% [markdown]
# ---
#
# **Question 20 (1 point).** What does the $p$-value given by your output in Question 19 mean?
#
# - `'a'`: The probability that social lobbying is more effective than office lobbying
# - `'b'`: The probability that social lobbying is not more effective than office lobbying
# - `'c'`: The probability that we would see an estimate as large or larger than the one we did in the experiment if social lobbying and office lobbying were equally effective
# - `'d'`: The probability that we would see an estimate as large or larger than the one we did in the experiment if social lobbying were more effective than office lobbying
#
# Replace the `...` below with your answer. For example, to answer `'a'`, below you would write `q7.answer <- 'a'`.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q20.answer <- '...'
q20.answer # print your answer

# %% [markdown]
# -------
#
# **Question 21 (0.5 points).** Is the p-value you calculated in Question 7 "statistically significant" (when using the conventional definition of statistical significance we covered in class)? Enter `TRUE` or `FALSE` below.

# %%
p.val.is.stat.sig <- NULL # YOUR CODE HERE

p.val.is.stat.sig # print your answer

# %% [markdown]
# ------
#
# **Question 22 (1 point).** Dr. Luvs To Lobby is Stanford's Director of Government Affairs. He was rejected from Berkeley many years ago, and has hated Berkeley ever since. And now, Berkeley was even ranked as the #1 college, above Stanford! He's outraged. 😡 He wants to lobby the California state legislature to cut Berkeley's budget.
#
# Dr. Lobby is trying to decide how to go about lobbying California state legislators. He sees the results of the Grose et al. study on social lobbying we are considering here in Part 2 of the exam and writes this email to his colleagues:
#
# > I just read an analysis of data from a new study that shows that social lobbying is no more effective than office lobbying. I know this because, when the researchers compared social lobbying to office lobbying, they found no statistically significant difference between the two. When we go to lobby the legislature this week, this study shows that we should lobby them in their offices, and *avoid social lobbying* if possible.
#
# Is his interpretation correct? If so, why or why not?
#
# - `'a'`: Dr. Lobby is correct: the insignificant $p$-value shows the researcher's hypothesis that social lobbying works is wrong
# - `'b'`: Dr. Lobby is correct: the insignificant $p$-value shows that office lobbying is equally effective as social lobbying
# - `'c'`: Dr. Lobby is incorrect: the insignificant $p$-value shows that we cannot disprove a skeptic of social lobbying, but our best guess is still that social lobbying is more effective than office lobbying
# - `'d'`: Dr. Lobby is incorrect: because results from experiments are always ambiguous, we can't learn anything from the experiment about whether social lobbying is more effective
#
# Replace the `...` below with your answer. For example, to answer `'a'`, below you would write `q9.answer <- 'a'`.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q22.answer <- '...'
q22.answer # Print your answer

# %% [markdown]
# **Question 23 (1 point).** After graduation, you get a job at a law firm that specializes in constitutional law. The lawyer you are working with is getting ready to argue a case before the Supreme Court about a new law that restricts lobbying. But the lawyer has never taken a statistics class, so needs your help: the lawyer wants you to summarize the results of several recent studies for them, including the Grose et al. study we analyzed today.
#
# To help you, here's a reminder about the findings we've calculated from this dataset so far (make sure you have run the cells with your answer further up in the Notebook first so that you can print the output here):

# %%
# RUN THIS CELL

# This is the estimated effect of office lobbying relative to control (no lobbying)
office.effect

# %%
# RUN THIS CELL

# This is the estimated effect of social lobbying relative to control (no lobbying)
social.effect

# %%
# RUN THIS CELL

# This is the estimated effect of social lobbying relative to office lobbying
social.vs.office

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# Which of these statements is **NOT** correct?
#
# - `'a'`  This experiment shows that the office lobbying treatment doesn't have any effect.
# - `'b'`  This experiment suggests some evidence that social lobbying increased how likely legislators were to support bills.
# - `'c'`  This experiment suggests some evidence that social lobbying was more effective than office-based lobbying.
# - `'d'`  In this experiment, the estimated effect of social lobbying was not statistically significant, so a skeptic of the efficacy of social lobbying wouldn't be persuaded.

# %%
# Put your answer where the ... is below. Leave the quotes there.
# For example, to answer a, your answer would look like this: 'a'
q23.answer <- '...'
q23.answer # Print your answer

# %% [markdown]
# **Hooray, you are finished with the exam!  Congratulations!**
#
# Make sure to follow the steps below (the same steps we use for the in-class assignments and problem sets) to make sure you get credit!

# %% [markdown]
# ——
#
# # Submitting Your Notebook (please read carefully!)
#
# To submit your notebook...
#
# ### 1. Click `File` $\rightarrow$ `Save Notebook`.
#
# ### 2. Wait 5 seconds.
#
# ### 3. Select the cell below and hit run.

# %%
ottr::export("PS3_SP26_Midterm.ipynb")

# %% [markdown]
# After you hit "Run" on the cell above, click the download link. A .zip file should download to your computer.
#
# (If you make changes to your notebook, you'll need to hit save and then run the cell above again before you submit to get a new version of it.)
#
# ### 4. Submit the .zip file you just downloaded <a href="https://www.gradescope.com/" target="_blank">on Gradescope here</a>.
#
# Notes:
#
# - **This does not seem to work on Chrome for iPad or iPhone.** If you're using an iPad or iPhone, you need to download the file using **Safari**.
# - If your web browser automatically unzips the .zip file (so you see a folder instead of a .zip file), you can just upload the .ipynb file that is inside the folder.
# - If this method is not working for you, try this: hit `File`, then `Save Notebook As`, then and submit the `Notebook (.ipynb)` file.
# - **If you are having technical difficulties** (i.e., you can't download your zip file or can't upload the file to Gradescope), **raise your hand to show your GSI immediately and email your Notebook (.ipynb) file to your GSI**. If your GSI is not available, show it to another GSI. Do this **before** the midterm is due.
# - **No late submissions are accepted**.  Some students have specific deadlines due to DSP accommodations.  If you do not have a DSP accommodation, **you must submit the exam by 9:30 AM to receive credit.**

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit.

# %%
ottr::export("PS3_SP26_Midterm.ipynb", pdf = TRUE, force_save = TRUE)
