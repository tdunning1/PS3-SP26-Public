# %% [markdown]
# # POLISCI 3

# %% [markdown]
# ## Week 9, Individual Activity 1: Discontinuity designs
#
# **Note**: As usual, this group activity is the same as the individual activity, but you will be able to check your answers to all the questions (not just the data analysis questions).
#
# In this in-class activity, you will review and practice what you have learned in the lectures and section about discontinuity designs.  The code is similar to what we used in the Week 9 Notebook Lecture.

# %% [markdown]
# ### An example: electronic voting in Brazil
#
# We're going to continue working with the Hidalgo study of the effects of electronic voting in Brazil.  (The paper is on bCourses as optional reading, but you do not need the paper to complete this activity).
#
# Let's load the data:

# %%
# RUN THIS CELL

# Load the libraries we'll need

library(estimatr)
library(rdrobust)

# Load Hidalgo's data set on electronic voting in Brazil

brazil.data <- read.csv("hidalgo_brazil_PS3.csv")
head(brazil.data)

# %% [markdown]
# A reminder what the columns in the data set mean:
#
# Municipality identifiers:
#
# - `ibge.municode` is a numeric code for each municipality in the dataset (these are codes produced by IBGE, the Brazilian statistics agency).
# - `uf` is an abbreviation for the state ("unidade federativa"); RO, for example, is the Brazilian state of Rondônia.
# - `muni` is the name of the municipality.
#
# The running, treatment, and outcome variables:
# - `electorate.96` is the size of the electorate (number of voters) in 1996.  This is the "**forcing**", "**assignment**", or "**running**" **variable** (these are all synonyms): it is the variable, the value of which determines whether a municipality receives the treatment (here, electronic voting) or not.
# - `comp.voting.98` is the **treatment variable**: i.e., it is a binary variable for whether computer (electronic) voting was introduced or not in the given municipality in 1998.
# - `depfedbranconulo98.pct` is the **outcome variable**: the percentage of blank ("branco") and invalid ("nulo") votes in the election for federal deputies ("depfed") in 1998.
#
# Covariates:
# - `blank.inv.96` is the percentage of blank and invalid votes in the previous election in 1996.  Note that this is the "lagged" outcome variable.
# - `poverty_high_1991` is a measure of municipal poverty in 1991;
# - `frac_25_illit_1991` is a measure of illiteracy in the municipality in 1991;
# - `gini_1991` is a measure of inequality in the municipality in 1991 (based on the "Gini" coefficient);
# - `pt_pres_1994` is the vote share of a particular political party, the Worker's Party (PT) in 1994;
# - `latitude` is the latitude of the municipality; and
# - `longitude` is the longitude of the municipality.
#
# (Note you need to scroll over to the right to see all of these variables in the print-out above).

# %% [markdown]
# **Question 1 (1 point)**. Let's begin by replicating the analysis of treatment effects in the Week 9 Notebook Lecture.
#
# First, subset the data to the 5,000 voter bandwidth around the threshold of 40,500---that is, include municipalities with a 1996 electorate of at least 35,500 voters and no more than 45,500 voters.
#
# Then, use the `difference_in_means` function to estimate the effect of computer voting.
#
# **Hints**: remember the outcome variable is `depfedbranconulo98.pct` and the treatment variable is `comp.voting.98`.  Recall how to subset on two conditions (we saw this in week 4 -- look at the R Cheat Sheet!). Also, remember not to use commas when writing numbers in R!
#
# For the data analysis problems in the problem set, you will be able to check your answer using the otter cell at the end of the question.

# %%
# Remember, replace NULL with your solution

# subset to the bandwidth used by Hidalgo: municipalities with a 1996 electorate of at least 35,500 voters and no more than 45,500 voters

close_brazil_data <- NULL # YOUR CODE HERE

# Now calculate the treatment effect using `difference_in_means`
dim_close <- NULL # YOUR CODE HERE

dim_close # print the result

# %%
. = ottr::check("tests/q1.R")

# %% [markdown]
# You've replicated the analysis in Hidalgo -- well done!  Now, consider a conceptual question about what you did in Question 1.

# %% [markdown]
# **Question 2 (1 point)**.  Which of the following ways to complete the following sentence describing the analysis in Question 1 is **NOT** correct?
#
# "The effect we estimated is called a ***local* average treatment effect (LATE)** because...
#
# - `'a'` the units of observation in this study of electronic voting in Brazil are municipalities, i.e., localities."
#
# - `'b'` the effect for this subset of municipalities located near the threshold is not necessarily the same as the effect for municipalities farther away from the threshold."
#
# - `'c'` the effect is defined and estimated only for municipalities no more than 5,000 voters away from the threshold in either direction---i.e., those near or `local' to the threshold. "
#
# - `'d'` the effect is defined as the average potential outcome under treatment minus the average potential outcome under control, among municipalities with a 1996 electorate of at least 35,500 voters and no more than 45,500 voters."
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q2.answer <- 'a'`.

# %%
q2.answer <- '...'
q2.answer # Print your answer

# %%
. = ottr::check("tests/q2.R")

# %% [markdown]
# Now, you might wonder whether a bandwidth of 5,000 voters on either side of the threshold of 40,500 voters is the right one. One question we might want to answer: how would the estimated effect vary if we use different subsets of data?  We'll investigate that question next.

# %% [markdown]
# **Question 3**. Let's estimate the local average treatment effect using three different sets of data---one smaller subset than in Question 1, one bigger subset, and then the full set of data we used in Notebook Lecture 1.
#
# **Question 3a (1 point)**. First, subset the data to the 2,500 voter bandwidth around the threshold of 40,500---that is, include municipalities with a 1996 electorate of at least 38,000 voters and no more than 43,000 voters.
#
# Then, use the `difference_in_means` function to estimate the effect of computer voting.
#
# **Hint**: See the hints to Question 1!

# %%
# subset the data

closest_brazil_data <- NULL # YOUR CODE HERE

# Now calculate the treatment effect using `difference_in_means`
dim_closest <- NULL # YOUR CODE HERE

dim_closest # print the result

# %%
. = ottr::check("tests/q3a.R")

# %% [markdown]
# **Question 3b (1 point)**. Now, subset the data to the 10,000 voter bandwidth around the threshold of 40,500---that is, include municipalities with a 1996 electorate of at least 30,500 voters and no more than 50,500 voters.
#
# Then, use the `difference_in_means` function to estimate the effect of computer voting.
#
# **Hint**: See the hints to Question 1!

# %%
# subset the data

less_close_brazil_data <- NULL # YOUR CODE HERE

# Now calculate the treatment effect using `difference_in_means`
dim_less_close <- NULL # YOUR CODE HERE

dim_less_close # print the result

# %%
. = ottr::check("tests/q3b.R")

# %% [markdown]
# **Question 3c (1 point)**. Finally, create the full data set we used for the graph with `rdplot()` in the Week 9 Notebook Lecture---that is, include municipalities with a 1996 electorate of 0 voters or more but no more than 100,000 voters.
#
# Then, use the `difference_in_means` function to estimate the effect of computer voting in this full data set.
#
# **Hint**: See the hints to Question 1!

# %%
# subset the data to municipalities with a 1996 electorate of 0 voters or more but no more than 100,000 voters.

full_brazil_data <- NULL # YOUR CODE HERE

# Now calculate the treatment effect using `difference_in_means`
dim_full <- NULL # YOUR CODE HERE

dim_full # print the result

# %%
. = ottr::check("tests/q3c.R")

# %% [markdown]
# #### Discussion
#
# Notice that the subsets you created in Question 1 and Question 3 include progressively more data (i.e., a larger number of municipalities), as we get further and further from the threshold of 40,500 voters:

# %%
# RUN THIS CELL

nrow(closest_brazil_data)
nrow(close_brazil_data)
nrow(less_close_brazil_data)
nrow(full_brazil_data)

# %% [markdown]
# (Remember, as discussed in the Week 9 Notebook Lecture, `nrow()` tells you the number of rows in a dataset -- and thus the number of observations.  See also the R Cheat Sheet for this week).
#
# This note leads to two further questions about choosing bandwidths in discontinuity designs:

# %% [markdown]
# **Question 4 (1 point)**: if we change nothing else in our analysis (other than the size of the bandwidth), should the standard error of the estimate using `full_brazil_data` be smaller than, the same as, or greater than with the `closest_brazil_data` subset?  Or is it impossible to tell with only the information provided?
#
# - `'a'` Standard error should be smaller.
#
# - `'b'` Standard error should be about the same.
#
# - `'c'` Standard error should be larger.
#
# - `'d'` It's impossible to tell with only the information provided.
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q4.answer <- 'a'`.

# %%
q4.answer <- '...'
q4.answer # Print your answer

# %%
. = ottr::check("tests/q4.R")

# %% [markdown]
# **Question 5 (1 point)**. Given your analysis and answers to the previous questions, you might think that it would be best to estimate effects using the largest possible dataset in a discontinuity design---for example, by using a full data set like `full_brazil_data`.
#
# Which of the following is **NOT** a reason why, in fact, we might want to use a smaller subset of the data, such as the `close_brazil_data` or `closer_brazil_data` subsets?
#
# - `'a'` If we use the full data, we risk confounding: there may be omitted variables associated with both assignment to treatment and the outcome.
#
# - `'b'` If we use the full data, our estimators of the average treatment effect might be biased.
#
# - `'c'` If we use a smaller subset of the data, our standard errors will tend to be larger.
#
# - `'d'` If we use a smaller subset of the data, we may limit confounding and reduce bias in estimators of the average treatment effect.
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q4.answer <- 'a'`.

# %%
q5.answer <- '...'
q5.answer # Print your answer

# %%
. = ottr::check("tests/q5.R")

# %% [markdown]
# Note that Questions 4 and 5 help to illustrate an important tradeoff between "bias" and "noise" when it comes to bandwidth selection in discontinuity designs.  We will discuss this idea together at the end of class.

# %% [markdown]
# ### Covariate balance tests
#
# Remember, we have tools at our disposal to test whether key conditions like local as-if random assignment hold. For example, we have already discussed the use of covariate balance tests. These tools can help also us choose the right bandwidth size in discontinuity designs.
#
# In the next two questions, you will think more about how to use these tools in the Brazil electronic voting study.
#
# This exercise will help illustrate why we may want to choose a narrow bandwidth in discontinuity designs (per Question 5).

# %% [markdown]
# **Question 6 (1 point)**. First, use `rdplot()` to create a graph like the one in the Week 9 Notebook Lecture--but this time using the lagged outcome variable, `blank.inv.96`. You should use the subset `full_brazil_data` you created in Question 3c.
#
# *Hint*: look at the R Cheat Sheet or the Week 9 Notebook Lecture to remember the syntax to use with `rdplot()`.  Remember that the outcome variable `blank.inv.96` is the first argument in the function, while the running variable `electorate.96` is the second. You will need to use the dataset$variable syntax for each variable. Also, don't forget to specify the value of the cutoff, c=...!

# %%
# Replace NULL with your code

lagged_outcome_plot <- NULL # YOUR CODE HERE

# %%
. = ottr::check("tests/q6.R")

# %% [markdown]
# Your plot should show, visually at least, that there is no big discontinuity in the value of the pre-treatment covariate.
#
# In other words, there is no apparent "effect" on the lagged outcome, i.e. blank/invalid votes in 1996---while, as we saw in the Notebook Lecture, there is a big effect on the actual outcome, i.e. blank/invalid votes in 1998.
#
# Remember, we saw in the Week 9 Notebook Lecture that this covariate is highly prognostic: the correlation with the actual outcome variable is about 0.49. So this seems quite convincing as a test of (local) randomization in the discontinuity design.
#
# We can test this more systematically, however. We will do this in Question 7.

# %% [markdown]
# Now, let's look at two more differences in means, using `full_brazil_data`. The outcome variables are the measures of poverty and illiteracy for municipalities.

# %%
# RUN THIS CELL

# This is the difference of average poverty in treatment and control, using the full data
difference_in_means(poverty_high_1991 ~ comp.voting.98, full_brazil_data)

# This is the difference of average illiteracy in treatment and control, using the full data
difference_in_means(frac_25_illit_1991 ~ comp.voting.98, full_brazil_data)

# This is the difference of average poverty in treatment and control, using the "close" data (narrow bandwidth)
difference_in_means(poverty_high_1991 ~ comp.voting.98, close_brazil_data)

# This is the difference of average illiteracy in treatment and control, using the "close" data (narrow bandwidth)
difference_in_means(frac_25_illit_1991 ~ comp.voting.98, close_brazil_data)

# %% [markdown]
# **Question 7 (1 point)**.  Thinking about your results in Question 7 and the two additional differences in means above, which of the following is **NOT** a correct interpretation of the results?
#
# - `'a'` Bigger municipalities appear to be unlike smaller municipalities.  In particular, in the full data, smaller municipalities are poorer and have higher illiteracy rates.
#
# - `'b'` The analysis suggests the likelihood of confounding if we use the full data: poverty and illiteracy are related to assignment to the treatment (electronic voting) and likely to the outcome (the rate of blank and invalid votes) as well.
#
# - `'c'` Near the threshold, we can be certain that confounding variables are absent.
#
# - `'d'` Near the threshold, the influence of confounding variables should be minimal, because while treatment status changes discontinuously at the threshold, the values of confounding variables do not.
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q8.answer <- 'a'`.

# %%
q7.answer <- '...'
q7.answer # Print your answer

# %%
. = ottr::check("tests/q7.R")

# %% [markdown]
# You are finished with the formal questions for this activity!
#
# In your group, however, please discuss what your analysis suggests about answers to the following questions:
# - Why, in a discontinuity design, do we often use only the data near the cutoff value of the running variable?
# - What are the advantages and disadvantages of thereby estimating a "local" average treatment effect (a LATE)?
# - How does the choice of a bandwidth size around the cutoff induce a tradeoff between "bias" and "noise"?

# %% [markdown]
# ——
#
# # Submitting Your Notebook (please read carefully!)
#
# To submit your notebook...
#
# ### 1. Click `File` $\rightarrow$ `Save Notebook`.
#
# ### 2. Wait 5 seconds.
#
# ### 3. Select the cell below and hit run.

# %%
ottr::export("PS3_SP26_Week9_GroupActivity.ipynb")

# %% [markdown]
# After you hit "Run" on the cell above, click the download link. A .zip file should download to your computer.
#
# (If you make changes to your notebook, you'll need to hit save and then run the cell above again before you submit to get a new version of it.)
#
# ### 4. Submit the .zip file you just downloaded <a href="https://www.gradescope.com/" target="_blank">on Gradescope here</a>.
#
# Notes:
#
# - **This does not seem to work on Chrome for iPad or iPhone.** If you're using an iPad or iPhone, you need to download the file using **Safari**.
# - If your web browser automatically unzips the .zip file (so you see a folder instead of a .zip file), you can just upload the .ipynb file that is inside the folder.
# - If this method is not working for you, try this: hit `File`, then `Download as`, then and submit the `Notebook (.ipynb)` file.
# - **If you are having technical difficulties** (i.e., you can't download your zip file or can't upload the file to Gradescope), **raise your hand to show your GSI immediately and email your Notebook (.ipynb) file to your GSI**. Do this before the assignment is due at 8:45 AM and definitely no later than 8:50 AM!
# - **No late submissions are accepted** (i.e. **no submissions allowed after 8:50 AM**). Note that assignments are due at 8:45 AM but the submission window on Gradescope closes at 8:50 AM. So 8:50 AM is the final time you can submit either on Gradescope (or to your GSI if you had technical problems).

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit.

# %%
ottr::export("PS3_SP26_Week9_GroupActivity.ipynb", pdf = TRUE, force_save = TRUE)
