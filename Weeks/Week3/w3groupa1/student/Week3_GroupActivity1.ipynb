# %% [markdown]
# # POLSCI 3
#
# ## Week 3, Group Activity 1: Averages, Standard Deviations, and Correlations

# %% [markdown]
# This assignment is identical to the individual assignment this week, **except for the discussion questions at the end.**
#
# Please work through questions 1-4 with your group members.
#
# You should also be able to check your answers to the autograded questions.
#
# Then, discuss questions 5a-c together.  **Today you will not need to type answers to the discussion questions**, and you do not need to include any answers to these questions when one of your group members submits your group's file to Gradescope.

# %%
# FIRST, SELECT THIS CELL AND HIT THE RUN BUTTON
library(testthat)
library(ottr)

# %% [markdown]
# Now let's read in the same data we used in the Notebook Lectures this week:

# %%
happiness_data <- read.csv('happiness_polity_2018.csv')
head(happiness_data)

# %% [markdown]
# Recall that this dataset contains data from world countries in terms of factors such as happiness levels, political regime type, and demographic information. Here's a codebook:
#
# - <code>polity2</code>: The "Polity Score" of the country, which measures the "democraticness" of its political regime on a 21-point scale ranging from -10 (hereditary monarchy) to +10 (consolidated democracy).
# - <code>polity2_cat</code>: The political category the country is identified within "autocracies" are on one end of the spectrum, "anocracies" are in the middle (semi-democracies), and "democracies" are at the top of the spectrum.
# - <code>gdpcapita</code>: GDP per capita (economic output per person)
# - <code>gdpcapita_cat</code>: GDP/income category that the country falls into (based on GDP per capita)
# - <code>happiness</code>: The country's happiness index, measured through surveys that require participants to rank their quality of life on a scale from 0 (worst possible life for them) to 10 (best possible life for them)
# - <code>happiness_cat</code>: Happiness category that the country falls into (based on happiness indicator)
# - <code>life_expectancy</code>: Average life expectancy in years
# - <code>life_expectancy_cat</code>: Life Expectancy category that the country falls into

# %% [markdown]
# ### **<span style="color:red">Instructions: In each of the questions, complete the cells by replacing "`# YOUR CODE HERE`" within the code cell with the right answer.</span>**

# %% [markdown]
# ------
#
# **Question 1:** First, let's calculate the averages of the happiness variable (<code>happiness</code>), the democracy variable (<code>polity2</code>), and GDP per capita (<code>gdpcapita</code>).
#
# **Hint**: Make sure you have run the cell above that reads in the data first!
#
# **Question 1a:** Happiness

# %%
# Calculate the average of the happiness variable in the happiness dataset, save it in happiness_ave
happiness_ave <- NULL # YOUR CODE HERE
happiness_ave

# %%
. = ottr::check("tests/q1a.R")

# %% [markdown]
# **Question 1b:** Democracy

# %%
# Calculate the average of the democracy variable in the happiness dataset, save it in democracy_ave
democracy_ave <- NULL # YOUR CODE HERE
democracy_ave

# %%
. = ottr::check("tests/q1b.R")

# %% [markdown]
# **Question 1c**: GDP per capita

# %%
# Calculate the average of the GDP per capita variable in the happiness dataset, save it in gdpcapita_ave
gdpcapita_ave <- NULL # YOUR CODE HERE
gdpcapita_ave

# %%
. = ottr::check("tests/q1c.R")

# %% [markdown]
# **Question 2** Now, let's do the same thing for the standard deviation. Thus, we'll use R to calculate the standard deviation of the happiness variable (<code>happiness</code>), the democracy variable (<code>polity2</code>), and GDP per capita (<code>gdpcapita</code>).

# %% [markdown]
# **Question 2a**: Happiness

# %%
# Calculate the standard deviation of the happiness variable in the happiness dataset, save it in happiness_sd
happiness_sd <- NULL # YOUR CODE HERE
happiness_sd

# %%
. = ottr::check("tests/q2a.R")

# %% [markdown]
# **Question 2b**: Democracy

# %%
# Calculate the standard deviation of the democracy variable in the happiness dataset, save it in democracy_sd
democracy_sd <- NULL # YOUR CODE HERE
democracy_sd

# %%
. = ottr::check("tests/q2b.R")

# %% [markdown]
# **Question 2c** GDP per capita

# %%
# Calculate the standard deviation of the GDP per capita variable in the happiness dataset, save it in gdp_sd
gdp_sd <- NULL # YOUR CODE HERE
gdp_sd

# %%
. = ottr::check("tests/q2c.R")

# %% [markdown]
# **Question 3** Standardizing variables.  Now, let's practice putting these same three variables in standard units.
#
# **Hints**:
#
# - Remember that when you standardize a variable, you first subtract the mean of the variable from the value of the variable for each unit. In R, you do this subtraction as follows: variable_name - mean(variable_name).
#
#     - Remember, you have to tell R where to find variable_name! So use the name of the dataset and the $ operator so that R picks the right column of the dataset!
#
#     - You already calculated mean(variable_name) for each variable in Question 1, so you can use the name of the variable you created for that if you wish.
#
# - Next, you need to divide by the standard deviation of variable_name. (Here, you can choose to use the variable where you stored the sd of variable_name in Question 2 if you like). For dividing, remember the "/" operator in R!
#
# In total, after following the hints, you will have one expression in the numerator, and another in the denominator.  It may be useful/necessary to surround the expression in the numerator in parentheses, so that R knows there is one thing in the numerator divided by another thing in the denominator.
#
# This procedure will give you the variable in standard units.
#
# **Question 3a** Happiness

# %%
# Put the happiness variable into standard units
happiness_standardized <- NULL # YOUR CODE HERE
happiness_standardized

# %%
. = ottr::check("tests/q3a.R")

# %% [markdown]
# **Question 3b** Democracy

# %%
# Put the democracy variable into standard units
democracy_standardized <- NULL # YOUR CODE HERE
democracy_standardized

# %%
. = ottr::check("tests/q3b.R")

# %% [markdown]
# **Question 3c** GDP per capita

# %%
# Put the GDP per capita variable into standard units
gdp_standardized <- NULL # YOUR CODE HERE
gdp_standardized

# %%
. = ottr::check("tests/q3c.R")

# %% [markdown]
# **Question 4** Finally, create a scatterplot showing the relationship between happiness and democracy. You will also calculate the correlation between the two variables.
#
# **Question 4a** Create a scatterplot of democracy against happiness. Make R write the word "Democracy" as the label for the horizontal ("x") axis and "Happiness" as the label for the vertical ("y") axis. Do not create an overall title for the plot or do any other formatting.
#
# **Hints** The R syntax <code>plot(x_variable,y_variable)</code> puts the variable x_variable on the horizontal axis and the variable y_variable on the vertical axis. Remember <code>xlab=</code> and <code>ylab=</code> for the labels!

# %%
happiness_life_plot <- NULL # YOUR CODE HERE
happiness_life_plot

# %%
. = ottr::check("tests/q4a.R")

# %% [markdown]
# **Question 4b** Now calculate the correlation between Democracy and Happiness. **Hint**: use <code>cor()</code>!  It does not matter in what order you enter the two arguments inside the parentheses of this function: the correlation of Democracy and Happiness is the same as the correlation of Happiness and Democracy!  (This is because, from the recorded lecture, the correlation coefficient is based on the sum of the products of two standardized variables; and $x * y$ is the same as $y*x$!)

# %%
cor_democracy_happiness <- NULL # YOUR CODE HERE
cor_democracy_happiness

# %%
. = ottr::check("tests/q4b.R")

# %% [markdown]
# **DISCUSSION QUESTIONS**
#
# Today, please discuss these questions with your group members, **without typing the answers anywhere**.  We will discuss the questions as a group at the end of class, and perhaps some of you can offer your thoughts.
#
# **Question 5a** Consider the scatterplot you created in Question 4a.  Looking at that scatterplot, do you think the correlation coefficient is a helpful tool for summarizing association?  Why or why not?
#
# **Question 5b** Recall our discussion of nomological/construct validation in class on Tuesday. Give the definition of this type of measurement validation. Does the extent of correlation between democracy and happiness help with construct validation for the happiness measure?  Why or why not?
#
# **Question 5c** How about the other types of measurement validity we discussed---face validity, content validity, and convergent/discriminant (or criterion) validation.  Do you think the happiness measure is like to be valid by these criteria?  Do any of our empirical results (in the Notebook Lectures or in this assignment) help validate the happiness measure, for any of these types of validation?

# %% [markdown]
# ----
#
# # Submitting Your Notebook (please read carefully!)
#
# To submit your notebook...
#
# ### 1. Click `File` $\rightarrow$ `Save and Checkpoint`.
#
# ### 2. Wait 5 seconds.
#
# ### 3. Select the cell below and hit run.

# %%
ottr::export("Week3_GroupActivity1.ipynb")

# %% [markdown]
# After you hit "Run" on the cell above, click the download link. A .zip file should download to your computer.
#
# (If you make changes to your notebook, you'll need to hit save and then run the cell above again before you submit to get a new version of it.)
#
# ### 4. Submit the .zip file you just downloaded <a href="https://www.gradescope.com/" target="_blank">on Gradescope here</a>.
#
# Notes:
#
# - **This does not seem to work on Chrome for iPad or iPhone.** If you're using an iPad or iPhone, you need to download the file using **Safari**.
# - If your web browser automatically unzips the .zip file (so you see a folder instead of a .zip file), you can just upload the .ipynb file that is inside the folder.
# - If this method is not working for you, try the "old way": hit `File`, then `Download as`, then `Notebook (.ipynb)` and submit that.
# - **Remember: sometimes the file takes a while to download, or the upload of the zip file to Gradescope takes time.**  There are a lot of people downloading and uploading at the same time in our class!!
# - **If the deadline for the individual assignment is expiring (the deadline is 8:45 AM) and you have not been able to upload, as a backup** you can then email your .zip file (or just the .ipynb file if you could not download the zip file) to your GSI. However, **please do not do email your GSI if you are able to upload the .zip file to Gradescope on time.**
# - **Please keep trying to upload to Gradescope past the individual assignment deadline even if you could not do so initially**---Gradescope will remain open for late submissions, and if you have emailed the full file to your GSI on time (if you could not do the upload in time), you will receive credit for an ontime submission.  However, **you need to upload to Gradescope to receive your grade for the assignment** (based on Gradescope's autograding capacity).

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit.

# %%
ottr::export("Week3_GroupActivity1.ipynb", pdf = TRUE, force_save = TRUE)
