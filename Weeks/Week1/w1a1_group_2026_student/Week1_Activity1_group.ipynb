# %% [markdown]
# # POLSCI 3
#
# ## Week 1, Group Activity 1: Analyzing Quantitative Data using R in Jupyter Notebooks

# %% [markdown]
# Working with your group, you will answer the same questions as in the individual assignment. At the end, there are two additional discussion questions.
#
# Only one member of the group will need to turn in the completed assignment, but each of you should please work through it as you go over the answers together.
#
# Look first again at *Stanford's* student store's sales from the past 5 months:

# %%
# FIRST, SELECT THIS CELL AND HIT THE RUN BUTTON
library(testthat)
library(ottr)

# %% [markdown]
# ### Part 1: Importing the Data

# %% [markdown]
# ### **<span style="color:red">Instructions: Complete the cells below by replacing "`# YOUR CODE HERE`" within the code cell with the right answer.</span>**

# %% [markdown]
# First of all, we need to load our data set into a variable for later reference.

# %% [markdown]
# This first line is already written for you. It saves the dataset that the command `read.csv('activity_notebook1.csv')` loads into a dataset named `suSales`. **Remember, you need to click this cell and hit "Run" to run it.**

# %%
suSales <- read.csv('activity_notebook1.csv')

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# Awesome! now let's take a look at our data.
#
# ------
#
# **Question 1:** Take a look at the content of suSales by simply typing `suSales`. Then hit run.
#
# **Hint**: If you see an error, it might be because you didn't run the cell above that reads in the data. You need to run that cell first before running the cell below.

# %%
# Replace "# YOUR CODE HERE" below with just suSales, then run this cell. You should see a table of data print out.
# YOUR CODE HERE

# %% [markdown]
# <!-- END QUESTION -->
#
# In this class, you'll always see a **codebook** that tells you what each variable in a dataset means right under the dataset. Here's what the variables mean in this dataset:
#
# - `Month`: What month of the year the sales refer to
# - `Hoodie`: How many Stanford hoodies sold that month
# - `Sweater`: How many Stanford sweaters sold that month
# - `OskiShirt`: How many Oski the Bear (Berkeley's mascot) shirts were sold that month

# %% [markdown]
# Hmmm. Who would've thought that Oski Shirts are such a big hit at Stanford? Something might off. Let's conduct some further investigation.

# %% [markdown]
# -------
#
# ### Part 2: Data Analysis

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **Question 2.** Print out the `OskiShirt` variable from `suSales`. If you're successful, you should see the contents of the `OskiShirt` column from the `suSales` data you saw above.
#
# **Hint:** This is where you use the `$`.

# %%
# Print the OskiShirt variable here, replacing "# YOUR CODE HERE" with the command to
# retrieve the OskiShirt column from suSales.
# YOUR CODE HERE

# %% [markdown]
# <!-- END QUESTION -->
#
# Nice! You know how to retrieve a variable from a dataset! Let's use this power to calculate the mean (also called average) of the OskiShirt variable. This will tell us, on average, how many OskiShirts the data says Stanford students purchase per month.
#
# ------
#
# **Question 3.** On the first line, replace "`NULL # YOUR CODE HERE`" with code that saves the mean of the `OskiShirt` variable into the variable called `oskiMean`. Then the second line, which is just `oskiMean`, will print out the answer you just saved. You don't need to modify the second line.

# %%
# Calculate mean of the OskiShirt in the suSales dataset, save it in oskiMean
oskiMean <- NULL # YOUR CODE HERE
oskiMean

# %% [markdown]
# ------
#
# **Question 4.** Now, do the same, but for the `Sweater` variable. In particular, on the first line, replace "`NULL # YOUR CODE HERE`" with code that calculates the mean of the `Sweater` variable and stores it in `sweaterMean`. Then the next line will print out the results you saved in `sweaterMean`.

# %%
# Calculate mean of Sweater, save in sweaterMean
sweaterMean <- NULL # YOUR CODE HERE
sweaterMean

# %% [markdown]
# Wait a minute. Take a look at how large you found `oskiMean` was versus how large `sweaterMean` was. It seems pretty strange that Stanford students are buying even more shirts with Oski the Bear than they are buying Stanford sweater.
#
# We asked Mr. Luzer (the store manager) about this since something seems strange. He realized there there was a mistake, and the dataset mistakenly recorded each Oski Shirt sale 4 times. So, we need to divide `oskiMean` by 4 to get the correct number of Oski shirts sold on the average month.
#
# ------
#
# **Question 5.** Divide the `oskiMean` variable by 4 and save it in the variable `oskiMeanCorrected`. Then, print `oskiMeanCorrected` again. (Again, replace "`NULL # YOUR CODE HERE`" with the answer.)
#
# Hint: Remember, R can do arithmetic! You already have `oskiMean`. Now, you just need to divide it by 4. Use `/` to divide.

# %%
# Store the true mean of Oski Shirt sales by dividing oskiMean by 4
oskiMeanCorrected <- NULL # YOUR CODE HERE
oskiMeanCorrected

# %% [markdown]
# Okay, that seems a bit more reasonable. Now we know that Stanford students really *do* love Oski the Bear! Who wouldn't?
#
# <img src="oski.jpeg" style="width: 50%"/>

# %% [markdown]
# ### Part 3: Subsetting

# %% [markdown]
# Finally, let's practice a few of the skills you learned in the short recorded Lecture this week.

# %% [markdown]
# Start by reading in the officer stop data:

# %%
officerdata <- read.csv('ps3_fl_officers_large.csv')
head(officerdata)

# %% [markdown]
# The cell above might take a few seconds to run, since it's a big dataset!
#
# Once again, this dataset contains real data on officers and drivers from nearly 860,000 police traffic stops. Each row represents one time that an officer stopped someone. Here is more information about the variables:
#
# - <code>search_occur</code>: Whether or not a search was conducted by the officer at that stop (0 = no search, 1 =  search)
# - <code>contra</code>: Whether or not a contraband (illegal items such as illegal drugs or guns) is found by the officer at that stop (0 = no contraband was found, either because officer did not search or because they did search and found none; 1 = contraband was found). *Officers only can find contraband if they conduct a search.*
# - <code>driver_age</code>: Age of driver (years)
# - <code>driver_race</code>: Race of driver (White = white; POC = non-white).
# - <code>officer_female</code>: Officer gender (0 = male; 1 = female). (There were no officers who identify with other genders in the dataset.)

# %% [markdown]
# In the recorded Notebook Lecture 2 (available on bCourses, along with the notebook), I subset `officerdata` to only observations where a female police officer conducted the stop and saved the result as a dataset `female.officer.stops`.  Later, I did the same for stops by male officers.
#
# Then, I calculated averages on these subset. For example, I compared the proportion of stops by female officers and stops by male officers that resulted in finding contraband.
#
# We'll practice doing similar subsetting in this problem.

# %% [markdown]
# **Question 6a.** Subset `officerdata` to only observations where a female police officer conducted the stop. Save the results in `female.officer.stops`.
#
# To do so, replace "`NULL # YOUR CODE HERE`" below with the correct code.
#
# * Hint: Use the `subset()` command. You can check the R Cheat Sheet in bCourses for a hint, too.*

# %%
female.officer.stops <- NULL # YOUR CODE HERE

# %%
. = ottr::check("tests/q6a.R")

# %% [markdown]
# Hint before you move on: run the cell above and it will tell you if you subsetted correctly. If you see "All tests passed!", it means you did!

# %% [markdown]
# ----
#
# **Question 6b.** Out of all the officer stops *conducted by female officers*, what proportion resulted in a search being conducted? Compute this by simply taking the mean of the `search_occur` variable in the `female.officer.stops` dataset, just like you learned in the recorded lecture this week. Save the result in a variable called `female.officer.search.rate`. In particular, replace "`NULL # YOUR CODE HERE`" below with code to take the mean of the `search_occur` variable in the `female.officer.stops` dataset that you just made.
#
# (On the second line, we multiply `female.officer.search.rate` by `* 100` before we print it out. This puts the answer in percentage points so it is easier to read. You don't need to change the second line.)

# %%
female.officer.search.rate <- NULL # YOUR CODE HERE
female.officer.search.rate * 100 # Don't change this line, it just prints the results in terms of a percentage.

# %%
. = ottr::check("tests/q6b.R")

# %% [markdown]
# ------
#
# **Question 6c.** Out of all of the stops instigated by *female* officers, what proportion resulted in contraband found? (That is, when looking at `female.officer.stops`, what is the average of the `contra` variable?) Save the resulting proportion in `female.officer.contra.found.rate`.
#
# Replace "`NULL # YOUR CODE HERE`" below with code to take the mean of the `contra` variable in the `female.officer.stops` dataset. On the second line, we again multiply this by 100 and print the result as a percentage to make it easier to interpret; you don't need to change the second line.

# %%
female.officer.contra.found.rate <- NULL # YOUR CODE HERE
female.officer.contra.found.rate * 100 # Don't change this line, it just prints the results in terms of a percentage.

# %%
. = ottr::check("tests/q6c.R")

# %% [markdown]
# ----
#
# **Question 6d.** Ideally, an officer would only search people when there is contraband to find. However, in real life, they search some people who don't have any contraband. **During what proportion of searches do female officers find contraband?**
#
# *Hint: You **can** take the subset of a subset!*

# %%
# Hint: First subset female.officer.stops to cases when they conduct a search
female.officer.searches <- NULL # YOUR CODE HERE

# Then compute the mean of contraband within female.officer.searches
female.officer.prop.searches.find.contra <- NULL # YOUR CODE HERE

# Don't change this line, it just prints the results in terms of a percentage.
female.officer.prop.searches.find.contra * 100

# %%
. = ottr::check("tests/q6d.R")

# %% [markdown]
# ## Discussion Questions
#
# Finally, please consider these discussion questions. These questions won't ask you to directly apply the techniques you learned. Instead, they'll ask you to step back and think about what you found. You might need to discuss what your findings mean with your group for a few minutes.
#
# First, run the cell below, which will make a small table that will compare the results for female officers with results from a similar analysis for male officers.

# %%
# RUN THIS CELL. YOU DON'T NEED TO UNDERSTAND ALL THE CODE NOW.
male.officer.stops <- subset(officerdata, officer_female == 0)
male.officer.search.rate <- mean(male.officer.stops$search_occur) 
male.officer.contra.found.rate <- mean(male.officer.stops$contra)
male.officer.searches <- subset(male.officer.stops, search_occur == 1) # SOLUTION
male.officer.prop.searches.find.contra <- mean(male.officer.searches$contra) # SOLUTION
data.frame(variable = c("% of Stops by Female Officers where they search",
                        "% of Stops by Female Officers where they find contraband",
                        "% of Searches by Female Officers where they find contraband",
                        "% of Stops by Male Officers where they search",
                        "% of Stops by Male Officers where they find contraband",
                        "% of Searches by Male Officers where they find contraband"),
          value = paste0(round(c(female.officer.search.rate,
                          female.officer.contra.found.rate,
                          female.officer.prop.searches.find.contra,
                          male.officer.search.rate,
                          male.officer.contra.found.rate, 
                          male.officer.prop.searches.find.contra) * 100, 2), "%"))

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **Question 7a.** Based on your analysis, do you think that female and male officers do their jobs any differently? If so, how?
#
# **Please limit your answer between 3-5 sentences for this question.** (To type your answer, **double click** where it says "Type your answer here..." and start typing.)

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# ------
#
# **Question 7b.** Suppose you work in the Mayor's office of a City and are trying to evaluate the performance of individual police officers. Do you think the proportion of stops where officers find contraband, or the proportions of searches where they find contraband, are a good indicator of the effectiveness/performance of police officers? Why or why not? What are the pros and cons of these metrics?
#
# **Please limit your answer between 3-5 sentences for this question.** (To type your answer, **double click**where it says "Type your answer here..." and start typing.)

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ------
#
# <span style="color:red">**Only one** group member needs to turn in a notebook for your entire group.</span>
#
# ------
# # Submitting Your Notebook (please read carefully!)
#
# To submit your notebook...
#
# ### 1. Click `File` $\rightarrow$ `Save Notebook`.
#
# ### 2. Wait 5 seconds.
#
# ### 3. Select the cell at the end of the notebook and hit run.
#
# ### 4. Submit the .zip file you just downloaded <a href="https://www.gradescope.com/" target="_blank">on Gradescope here</a>.
#
# (Note you might get some warning messages, but this should still produce a zip file you can download and then submit on Gradescope).

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit.

# %%
ottr::export("Week1_Activity1_group.ipynb", pdf = TRUE, force_save = TRUE)
