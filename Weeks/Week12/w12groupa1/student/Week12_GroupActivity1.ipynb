# %% [markdown]
# # POLSCI 3
#
# # Week 12, Group In-Class Activity
#
# **The group activity is the same as the individual activity, but you will be able to check all of your answers using the Otter cells.**
#
# The activity this week has two parts.
#
# In the first part, you'll apply multivariate regression to an observational dataset (the same one we used in Notebook Lecture 1).
#
# In the second part, you do so with an experiment (using data from the study we discussed in Notebook Lecture 2).
#
# You'll also answer conceptual questions about the anayses.
#
# In this notebook, whenever you are asked to run a regression, make sure to include the lm() calls inside the parentheses of the summary() function.  See the Notebook Lectures for Weeks 11 and 12 and the R Cheat Sheet for examples and the R commands that you need!
#
# ## Part 1: Multivariate Regression with Observational Data

# %% [markdown]
# First, let's read in the data.

# %%
# RUN THIS CELL
# import libraries
library(testthat)

data <- read.csv("ps3-house-election-spending.csv")
head(data)

# %% [markdown]
# Here is a quick rundown of what each column means:
#
# - `state`: State (e.g., for CA-13, "CA")
# - `district`: District number (e.g., for CA-13, 13)
# - `name_dem_cand`: Democrat candidate name in the 2020 US House elections
# - `name_rep_cand`: Republican candidate name in the 2020 US House elections
# - `dem_us_house_percent_2020`: Democrat candidate's vote share in 2020 election (percent)
# - `dem_us_house_percent_2018`: Democrat candidate's vote share in 2018 election (percent)
# - `dem_won_ushouse_2018`: A Democrat won the US House election in 2018, and so is running for re-election in 2020 (0 = Democrat lost/Republican won; 1 = Democrat won/Republican lost)
# - `clinton_percent_2016`: Clinton vote share in 2016 in the district (percent)
# - `spending_dem_ushouse_2020`: Democratic US House candidate's spending in 2020, in millions of dollars
# - `spending_rep_ushouse_2020`: Republican US House candidate's spending in 2020, in millions of dollars

# %% [markdown]
# -----
# For Questions 1a and 1b, you will be able to check your anwer using the Otter cells after the question.
#
# **Question 1a (0.5 points).** Subset the data to only districts where a *Republican* won in the 2018 election (based on `dem_won_ushouse_2018`). Store the new subset of the data in a new data frame called `republicans`.

# %%
# Subset to Republicans
republicans <- NULL # YOUR CODE HERE

# %%
. = ottr::check("tests/q1a.R")

# %% [markdown]
# -----
#
# **Question 1b (1 point).** You'd expect that when Republicans spend more, Democratic vote share would be *lower*. What do we find? Using bivariate regression that we learned last week, estimate the relationship between Democratic vote share in 2020 (`dem_us_house_percent_2020`, as the outcome) and Republican spending in 2020 (`spending_rep_ushouse_2020`, as a predictor variable). Do this with the `republicans` dataset.
#
# *Hint*: Remember to include the lm() call inside the parentheses of the wrap the summary() call!  See the Notebook Lectures for Weeks 11 and 12 and the R cheat sheet.

# %%
q1b <- NULL # YOUR CODE HERE
q1b # print your answer

# %%
. = ottr::check("tests/q1b.R")

# %% [markdown]
# ------
#
# **Question 2 (1 point).**  Run the same regression as you did above, but *also* control for both `clinton_percent_2016` and `dem_us_house_percent_2018`. Do this with the `republicans` dataset.

# %%
q2 <- NULL # YOUR CODE HERE
q2

# %%
. = ottr::check("tests/q2.R")

# %% [markdown]
# ------
#
# **Question 3a (0.5 points).**  Consider using your multivariate regressions in Question 2 to estimate the causal effect of `spending_rep_ushouse_2020` on `dem_us_house_percent_2020`. `TRUE` or `FALSE`: Since you've controlled for omitted variables, there is no more omitted variable bias.
#
# Save your answer in `q3.answer`. Do not use quotes. For example, to answer `TRUE`, type `q3.answer <- TRUE`.

# %%
q3.answer <- NULL # YOUR CODE HERE

# %%
. = ottr::check("tests/q3a.R")

# %% [markdown]
# **Question 3b (1 point).** Which of the following is **NOT** a correct explanation for the correct answer in Question 3a.
#
# - `'a'` It is plausible there is omitted variable bias, because there might be confounders we have not included in the regression.
# - `'b'` It is plausible there is self-selection bias, because the potential outcomes (i.e. the potential Democratic vote share) of districts that received more Republican campaign spending might be different than those that received less campaign spending.
# - `'c'` If the economy were doing worse ahead of the 2020 election in certain districts, Republican incumbents might have expected to do worse in elections in those districts. Knowing this, they might have raised and spent more money in those districts. This would result in a positive association between Republican spending and Democratic vote share.
# - `'d'` If the economy were doing worse ahead of the 2020 election in more competitive or Democratic-leaning districts, Republican politicians might have decided it was not worth it to raise and spend more money in those districts.  This would result in a positive association between Republican spending and Democratic vote share.
#
# Enter your answer below between quotes. For example, if you wanted to answer 'a', your answer would look like: `q3b.answer <- 'a'`.

# %%
q3b.answer <- '...'
q3b.answer # print your answer

# %%
. = ottr::check("tests/q3b.R")

# %% [markdown]
# ------
#
# **Question 4 (1 point).** Which one of the following statements about the estimate (0.20177) of the `dem_us_house_percent_2018` variable in Question 2 **IS** correct?
#
# - `'a'`: On average, a 1-percent increase in the Democratic house vote in 2018 causes the 2020 Democratic house vote to increase by approximately 0.2%.
# - `'b'`: On average, a 1-percent increase in the Democratic house vote in 2018 causes the 2020 Democratic house vote to increase by approximately 0.2%, holding constant the other variables.
# - `'c'`: On average, districts where the Democratic house vote in 2018 is 1-percent higher is associated with a 0.2% higher 2020 Democratic house vote.
# - `'d'`: On average, districts where the Democratic house vote in 2018 is 1-percent higher is associated with a 0.2% higher 2020 Democratic house vote, holding constant the other variables.
#
# Enter your answer below between quotes. For example, if you wanted to answer 'a', your answer would look like: `q4.answer <- 'a'`.

# %%
q4.answer <- '...'

# %%
. = ottr::check("tests/q4.R")

# %% [markdown]
# **BONUS QUESTION!**  The following Question 5 will not be added to the total points possible on Gradescope, but answering it correctly will increase your score on this activity by 1 point!  (If you are short on time, you can skip it and return to it at the end).
#
# **Question 5.** Which of the following is **NOT** a correct explanation for why the estimated relationship between `spending_rep_ushouse_2020` and `dem_us_house_percent_2020` changes, once you add the control variables `clinton_percent_2016` and `dem_us_house_percent_2018` to the regression?
#
# - `'a'`: When we include the control variables, it is as if we ran a regression of `spending_rep_ushouse_2020` on the residuals from the regression of `dem_us_house_percent_2020` on the control variables.
# - `'b'`: When we include the control variables, we effectively remove the variation in `dem_us_house_percent_2020` that is associated with them---leaving only whatever variation in `spending_rep_ushouse_2020` is not associated with the control variables.
# - `'c'`: The control variables are probably not associated with `dem_us_house_percent_2020`, so including them should make little difference to the results.
# - `'d'`: The control variables are probably associated, empirically, with `dem_us_house_percent_2020`, because the vote shares for a particular party tend to be fairly similar over time in a given district.
#
# Enter your answer below between quotes. For example, if you wanted to answer 'a', your answer would look like: `q5.answer <- 'a'`.

# %%
q5.answer <- '...'
q5.answer # Print your answer

# %%
. = ottr::check("tests/q5.R")

# %% [markdown]
# ## Part 2: Multivariate Regression with Experimental Data
#
# In this second part of the activity, you will analyze the experiment discussed in Notebook Lecture 2.

# %%
# RUN THIS CELL to read in the data

data_phones <- read.csv("ps3_phonecall_clean.csv")
head(data_phones)

# %% [markdown]
# This is the same data as from the recorded lecture, but **there are new variables now!**
#
# In particular, the treatment variable now records not just the attitude of the speaker (the confederate with the phone) towards gender and work but also whether they wear a hijab (a head scarf that may cue Muslim religiosity to observers).  There are also two other covariates in the data set. Read below for more details.
#
# Each row in the dataset is one interaction where a person dropped their lemons at a German bus stop after talking on the phone. Here is a quick rundown of what each column means:
#
# - `treat`: **NEW VARIABLE** There are several values of the `treat` variable:
#     - `"German"`: The person who dropped the lemons was a native German who made a call (implying one of several gender attitudes I have collapsed into one category to make the data analysis easier).
#     - `"Imm w/ Hijab, Conservative Gender Att"`: The person who dropped the lemons was an immigrant wearing a hijab and made a call implying they had conservative gender attitudes.
#     - `"Imm w/ Hijab, Neutral Gender Att"`: The person who dropped the lemons was an immigrant wearing a hijab and made a call that did not imply anything about their gender attitudes.
#     - `"Imm w/ Hijab, Progressive Gender Att"`: The person who dropped the lemons was an immigrant wearing a hijab and made a call implying they had progressive gender attitudes.
#     - `"Imm w/o Hijab"`: The person who dropped the lemons was an immigrant who did not wear a hijab.
# - `anyhelp`: **outcome**: whether any bystander offered help
# - `bystander`: number of bystanders (measured before the treatment was implemented)
# - `femprop`: proportion of female bystanders (measured before the treatment was implemented)
# - `station1`: **NEW VARIABLE** the name of the station where the interaction took place
# - `team`: **NEW VARIABLE** the name of the team that implemented this experiment
#
# As a reminder, this is what the scene looked like:
#
# ![](scene.jpg)
#
# And here is what the treatments looked like:
#
# ![](treatments.jpg)

# %% [markdown]
# -----
#
# **Question 6 (1 point).** Run a regression that estimates the effect of `treat` on `anyhelp`, without using any other covariates.
#
# *Hints*: notice that in the code chunk you ran above for this Part 2, we read in the data for the study as `data_phones`.  Again, remember to wrap your `lm()` call within the parentheses of your `summary()` call!  See Notebook Lecture 2 and the R Cheat Sheet.
#
# You will be able to check your answer using the Otter cell after the question.

# %%
reg.no.covars <- NULL # YOUR CODE HERE
reg.no.covars

# %%
. = ottr::check("tests/q6.R")

# %% [markdown]
# ------
#
# **Question 7 (1 point).** Now, look at the regression output from Question 6. Which of the following interpretations is **NOT** consistent with the results of the experiment?
#
# In answering this question, you may wish to take another look at the codebook at the top of Part 2, which tells you exactly what happened in each treatment condition (see the bullet point under `treat` for the definitions).
#
# - `'a'` Germans appear to treat immigrants with hijabs who express progressive gender attitudes similarly to the way they treat immigrants without hijabs.
# - `'b'` Germans appear to discriminate against immigrant women wearing Hijabs (e.g. see the Neutral condition) relative to Germans.
# - `'c'` Germans appear to discrimiante less if an immigrant signals she has more liberal attitudes on gender (by making the progressive phone call or by not wearing a Hijab) and more if she signals she has more conservative gender attitudes.
# - `'d'` Germans in general appear to prefer to help immigrants rather than native Germans.
#
# Enter your answer below between quotes. For example, if you wanted to answer 'a', your answer would look like: `q7.answer <- 'a'`.

# %%
q7.answer <- '...'
q7.answer # Print your answer

# %%
. = ottr::check("tests/q7.R")

# %% [markdown]
# -----
#
# **Question 8 (1 point).** Run the same regression you ran in Question 6, but now also add the `femprop` and `station1` variables as control variables.

# %%
reg.with.controls <- NULL # YOUR CODE HERE

reg.with.controls # print the result

# %%
. = ottr::check("tests/q8.R")

# %% [markdown]
# **Question 9 (1 point)** Which of the following **IS** a valid difference between how we should interpret the numbers in the Estimate column next to the `femprop` variable and the numbers in Estimate column next to the treatment variables?

# %% [markdown]
# - `'a'` The numbers next to the treatment variables could turn out differently in different repetitions of the experiment, whereas the number next to `femprop` would be the same in different repetitions of the experiment.
# - `'b'` The numbers next to the treatment variables have a causal interpretation because the treatment was randomized, but the numbers next to the other covariates, such as `femprop`, do not have a causal interpretation because the covariates were not randomized.
# - `'c'` The number next to `femprop` should be interpreted as an estimate of a causal effect because `femprop` could itself be seen as an outcome variable in the experiment.
# - `'d'` The numbers next to the treatment variables could be biased due to omitted variables, if the control variables we included in the multivariate regression are not sufficient to remove confounding.
#
# Enter your answer below between quotes. For example, if you wanted to answer 'a', your answer would look like: `q9.answer <- 'a'`.

# %%
q9.answer <- '...'
q9.answer # Print your answer

# %%
. = ottr::check("tests/q9.R")

# %% [markdown]
# -----

# %% [markdown]
# ——
#
# # Submitting Your Notebook (please read carefully!)
#
# To submit your notebook...
#
# ### 1. Click `File` $\rightarrow$ `Save Notebook`.
#
# ### 2. Wait 5 seconds.
#
# ### 3. Select the cell below and hit run.

# %%
ottr::export("Week12_GroupActivity1.ipynb")

# %% [markdown]
# After you hit "Run" on the cell above, click the download link. A .zip file should download to your computer.
#
# (If you make changes to your notebook, you'll need to hit save and then run the cell above again before you submit to get a new version of it.)
#
# ### 4. Submit the .zip file you just downloaded <a href="https://www.gradescope.com/" target="_blank">on Gradescope here</a>.
#
# Notes:
#
# - **This does not seem to work on Chrome for iPad or iPhone.** If you're using an iPad or iPhone, you need to download the file using **Safari**.
# - If your web browser automatically unzips the .zip file (so you see a folder instead of a .zip file), you can just upload the .ipynb file that is inside the folder.
# - If this method is not working for you, try this: hit `File`, then `Save Notebook As`, then and submit the `Notebook (.ipynb)` file.
# - **If you are having technical difficulties** (i.e., you can't download your zip file or can't upload the file to Gradescope), **raise your hand to show your GSI immediately and email your Notebook (.ipynb) file to your GSI**. If your GSI is not available, show it to another GSI. Do this **before** the midterm is due.
# - Other than lateness due to technical difficulties verified by a GSI or Professor Dunning, **no late submissions are accepted**.  You must submit the assignment no later than 8:55 AM to receive credit.

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit.

# %%
ottr::export("Week12_GroupActivity1.ipynb", pdf = TRUE, force_save = TRUE)
