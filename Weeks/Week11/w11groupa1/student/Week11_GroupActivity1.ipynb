# %% [markdown]
# # POLISCI 3

# %% [markdown]
# ## Week 11 Group Assignment: Data visualization and bivariate regression
#
# **This activity is the same as the individual activity but you will be able to check all of your answers.**
#
# In this activity, you will be practicing scatterplot visualizations on your own. Let's start by reading in the Broockman Skovron (2018) data.

# %%
library(testthat)
library(ggplot2); options(warn=-1)

data <- read.csv('broockman_skovron.csv')
head(data)

# %% [markdown]
# Here is an overview of what the columns in the dataset represent:
#
# - `republican`: whether the state legislator or state legislative candidate who answered the survey was a Republican (1 = Republican, 0 = Democrat)
# - `incumbent`: whether the person who answered the survey was an incumbent representative (i.e., currently holds political office) (1 = already holds office, 0 = just a candidate)
# - `marriage_perception`: what percent of the politician's constituents they think support same-sex marriage
# - `marriage_opinion`: what percent of the politician's constituents actually support same-sex marriage
# - `religexempt_perception`: what percent of the politician's constituents they think support allowing employers to refuse to cover birth control for employees if it violates their religious beliefs
# - `religexempt_opinion`: what percent of the politician's constituents actually support allowing employers to refuse to cover birth control for employees if it violates their religious beliefs
# - `gunsbanassault_perception`: what percent of the politician's constituents they think support banning assault weapons
# - `gunsbanassault_opinion`: what percent of the politician's constituents actually support banning assault weapons

# %% [markdown]
# ------
#
# **Question 1 (1 point). Make a scatterplot _among Democratic legislators only_ where actual constituency support for same-sex marriage is on the x-axis and perceived constituency support for it is on the y-axis.**
#
# To do this, first subset the data to Democratic legislators (i.e., where `republican` is 0) and save the data in the `democrats.only` subset.
#
# Then, make a graph with `marriage_opinion` on the x axis and `marriage_perception` on the y axis, within the `democrats.only` dataset.
#
# **Do not** include a line of best fit yet.
#
# Note: you will be able to check your answer on this question using the Otter cell.

# %%
# First, subset the data to Democratic legislators only
democrats.only <- NULL # YOUR CODE HERE

# Now, make a scatter plot with marriage_opinion on the x axis and marriage_perception on the y axis,
# within the democrats.only dataset
dem.graph <- NULL # YOUR CODE HERE

dem.graph # Let's look at the graph. (This might take a couple seconds to run.)

# %%
. = ottr::check("tests/q1.R")

# %% [markdown]
# ------
#
# **Question 2. Add a line of best fit to the graph you made in Question 1.**

# %%
dem.graph.with.line <- NULL # YOUR CODE HERE

dem.graph.with.line # Let's look at the graph.

# %%
. = ottr::check("tests/q2.R")

# %% [markdown]
# ------
#
# **Question 3 (1 point). Now, make a scatterplot, _with_ a line of best fit _among Republican legislators only_ where actual constituency support for same-sex marriage is on the x-axis and perceived constituency support for it is on the y-axis.**
#
# To do this, first subset the data to Republican legislators (i.e., where `republican` is 1) and save the data in the `republicans.only` subset.
#
# Then, make a graph with `marriage_opinion` on the x axis and `marriage_perception` on the y axis, within the `republicans.only` dataset.
#
# **Do** also include a line of best fit on this graph (like you did in Question 2).

# %%
# First, subset the data to Republican legislators only
republicans.only <- NULL # YOUR CODE HERE

# Now, make a scatter plot with marriage_opinion on the x axis and marriage_perception on the y axis,
# within the republicans.only dataset, AND with a line of best fit added
rep.graph.with.line <- NULL # YOUR CODE HERE

rep.graph.with.line # Let's look at the graph. (This might take a couple seconds to run.)

# %%
. = ottr::check("tests/q3.R")

# %% [markdown]
# -------
#
# **Question 4 (1 point). Looking at the graph you made in Question 3, when legislative disricts in fact have 65% support for gay marriage, what does the average Republican state legislative candidate perceive the support to be?**
#
# (Make your best guess from looking at the graph. This question allows room for error of several percentage points on either side of the right answer.)
#
# **Enter your answer as a whole number without a percentage sign. For example, if you wanted to answer 65%, you would type `my.best.guess <- 65`.**

# %%
my.best.guess <- NULL # YOUR CODE HERE

my.best.guess # print your answer

# %%
. = ottr::check("tests/q4.R")

# %% [markdown]
# ------
#
# **Question 5. Which of these is _NOT_ a good reason to make this graph?**
#
# - `'a'`: To visualize the relationship between these variables
# - `'b'`: To understand if the relationship between these variables is statistically significant
# - `'c'`: To help understand what values of the Y axis variable we should expect to observe given a value of the X axis variable
# - `'d'`: To check if there might be patterns between these variables we might have missed from just numbers
#
# Replace the `...` below with your answer. For example, to answer `a`, the below would read `q5.answer <- 'a'`.

# %%
q5.answer <- '...'
q5.answer # print your answer

# %%
. = ottr::check("tests/q5.R")

# %% [markdown]
# Now, we are going to get into interpreting formal statistical output from a bivariate regression.
#
# **Question 6 (1 point). Run a regression predicting `gunsbanassault_perception` (outcome variable) with `gunsbanassault_opinion` (prediction variable) _among Democratic politicians_.**
#
# To do this, use the subset of the data for only Democratic politicians that you created in Question 1. Then, run the regression described above in that dataset.
#
# *Hint*: you should use `summary()` following the example in Notebook Lecture 2.  See also the R Cheat Sheet.  You will be able to check your answer to this question using the Otter cell.

# %%
# Run the regression in the democrats.only subset
dem.guns.lm <- NULL # YOUR CODE HERE

dem.guns.lm # Let's look at the results.

# %%
. = ottr::check("tests/q6.R")

# %% [markdown]
# **Question 7 (1 point). In a district where 55% of people support banning assault weapons, what would level of support would Democratic politicians guess there is?** Use the numbers from the regression in Question 6.
#
# **Note**: The average district has around 61% support, so we are not excessively extrapolating.
#
# You will be able to check you answer using the Otter cell after the question.

# %%
dems.guess.at.55 <- NULL # YOUR CODE HERE

dems.guess.at.55 # Let's look at the answer.

# %%
. = ottr::check("tests/q7.R")

# %% [markdown]
# **Question 8 (1 point). TRUE or FALSE: Democrats overestimate support for banning assault weapons in their districts.**
#
# *Hint*: Look at the information and results in Question 7 to answer this question.
#
# Save your answer in q8.answer. Do not use quotes. For example, to answer TRUE, type q8.answer <- TRUE.

# %%
q8.answer <- NULL # YOUR CODE HERE

q8.answer # print your answer

# %%
. = ottr::check("tests/q8.R")

# %% [markdown]
# ----
#
# Now, let's look at Republican politicians.
#
# **Question 9 (1 point). Run a regression predicting `gunsbanassault_perception` (outcome variable) with `gunsbanassault_opinion` (prediction variable) _among Republican politicians_.**
#
# To do this, use the subset the data for only Republican politicians you created in Question 3. Then, run the regression describe above in that dataset.

# %%
# Run the regression in the republicans.only subset
repub.guns.lm <- NULL # YOUR CODE HERE

repub.guns.lm # Let's look at the results.

# %%
. = ottr::check("tests/q9.R")

# %% [markdown]
# **Question 10 (1 point). As you can see above, the intercept term of the regression is lower for the regression predicting Democrats' answers than Republicans' answers. `TRUE` or `FALSE`: This shows that Democrats are less accurate than Republicans in predicting public opinion in their districts.**
#
# Save your answer in `q10.answer`. Do not use quotes. For example, to answer `TRUE`, type `q10.answer <- TRUE`.

# %%
q10.answer <- NULL # YOUR CODE HERE

q10.answer # print your answer

# %%
. = ottr::check("tests/q10.R")

# %% [markdown]
# **Question 11 (1 point). In a district where 55% of people support banning assault weapons, what would level of support would Republican politicians guess there is?** Use the numbers from the regression in Question 9.

# %%
repubs.guess.at.55 <- NULL # YOUR CODE HERE

repubs.guess.at.55 # Let's look at the answer.

# %%
. = ottr::check("tests/q11.R")

# %% [markdown]
# **Question 12 (1 point). Thinking about all of your different analyzes in this in-class activity, which of the following is **NOT** a correct interpretation of results from this study?**
#
# - `'a'` Both Democrat and Republican politicians underestimate public support for banning assault weapons.
# - `'b'` Republican politicians underestimate support for banning assault weapons even more than Democrats do.
# - `'c'` Republicans underestimate public support for gay marriage.
# - `'d'` Democrats overestimate public support for gay marriage.
#
# Replace the `...` below with your answer. For example, to answer `a`, the below would read `q11.answer <- 'a'`.

# %%
q12.answer <- '...'

q12.answer # print your answer

# %%
. = ottr::check("tests/q12.R")

# %% [markdown]
# ----
#
# # Submitting Your Notebook (please read carefully!)
#
# To submit your notebook...
#
# ### 1. Click `File` $\rightarrow$ `Save and Checkpoint`.
#
# ### 2. Wait 5 seconds.
#
# ### 3. Select the cell below and hit run.

# %%
ottr::export("Week11_Activity1.ipynb")

# %% [markdown]
# After you hit "Run" on the cell above, click the download link. A .zip file should download to your computer.
#
# (If you make changes to your notebook, you'll need to hit save and then run the cell above again before you submit to get a new version of it.)
#
# ### 4. Submit the .zip file you just downloaded <a href="https://www.gradescope.com/" target="_blank">on Gradescope here</a>.
#
# Notes:
#
# - **This does not seem to work on Chrome for iPad or iPhone.** If you're using an iPad or iPhone, you need to download the file using **Safari**.
# - If your web browser automatically unzips the .zip file (so you see a folder instead of a .zip file), you can just upload the .ipynb file that is inside the folder.
# - If this method is not working for you, you could hit `File`, then `Download as`, then `Notebook (.ipynb)` and submit that.  But please reach out to your GSI if you are having technical problems with the zip file download or file upload to Gradescope.
# - Make sure you submit to the Problem Set 3 assignment on Gradescope.

# %% [markdown]
# ----

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit.

# %%
ottr::export("Week11_GroupActivity1.ipynb", pdf = TRUE, force_save = TRUE)
