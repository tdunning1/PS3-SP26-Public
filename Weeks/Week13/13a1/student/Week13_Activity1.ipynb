# %% [markdown]
# # POLSCI 3
#
# # Week 13, Group In-Class Activity (Extra Credit Opportunity)
#
#
# - In this activity, please discuss the following questions with your group members:
#   - If you were to develop your final research project further (beyond this course), how could you use qualitative data, insights, and methods?
#   - E.g. what kind interviews could you conduct?  What sort of participant-observation or ethnographic research could be valuable?
#   - What kinds of qualitative observations might be most useful for evaluating your causal or descriptive hypotheses (in addition to statistical tests)?
#
# This is mainly hypothetical but you could use some of the insights from your discussion in your individual final project reports (for example, to discuss extensions of the research as well as limitations)
#
# After discussing these questions for 15-20 minutes with your group members, double click the Markdown cell below.  Then, type several of the points you discussed (your writing does not need to be extensive).  You can use the provided bullet point markers if you like.
#
# After typing your answers, complete QUESTION 1 by saving TRUE into q1.answer in the code chunk.
#
# Then, submit your Notebook on Gradescope to earn an extra credit point for every group member present.  The extra credit point will be applied to your in-class assignment scores. (If you are the only member of your group who is here, you can join another group, but be sure to submit your own Notebook to receive credit).

# %% [markdown]
# ### TYPE YOUR GROUP'S IDEAS HERE
#
# Type here some answers your group came up with:
#
# - INSERT HERE
#
# - INSERT HERE
#
# - INSERT HERE

# %% [markdown]
# **QUESTION 1. CLAIM YOUR EXTRA CREDIT POINT!**  If you would like to receive extra credit for the assignment, type TRUE below to save your answer in q1.answer.
#
# (This is just to prompt the autograder to assign you a point for the assignment).
#
# Do not use quotes. Thus, your answer should appear like this:
#
# q1.answer <- TRUE.

# %%
q1.answer <- NULL # YOUR CODE HERE

q1.answer # print your answer

# %%
. = ottr::check("tests/q1.R")

# %% [markdown]
# -----

# %% [markdown]
# ——
#
# Now submit your group's notebook, listing the names of all group members present, to claim your extra credit point.
#
# # Submitting Your Notebook (please read carefully!)
#
# To submit your notebook...
#
# ### 1. Click `File` $\rightarrow$ `Save Notebook`.
#
# ### 2. Wait 5 seconds.
#
# ### 3. Select the cell below and hit run.

# %%
ottr::export("Week13_Activity1.ipynb")

# %% [markdown]
# After you hit "Run" on the cell above, click the download link. A .zip file should download to your computer.
#
# (If you make changes to your notebook, you'll need to hit save and then run the cell above again before you submit to get a new version of it.)
#
# ### 4. Submit the .zip file you just downloaded <a href="https://www.gradescope.com/" target="_blank">on Gradescope here</a>.
#
# Notes:
#
# - **This does not seem to work on Chrome for iPad or iPhone.** If you're using an iPad or iPhone, you need to download the file using **Safari**.
# - If your web browser automatically unzips the .zip file (so you see a folder instead of a .zip file), you can just upload the .ipynb file that is inside the folder.
# - If this method is not working for you, try this: hit `File`, then `Save Notebook As`, then and submit the `Notebook (.ipynb)` file.
# - **If you are having technical difficulties** (i.e., you can't download your zip file or can't upload the file to Gradescope), **raise your hand to show your GSI immediately and email your Notebook (.ipynb) file to your GSI**. If your GSI is not available, show it to another GSI. Do this **before** the midterm is due.
# - Other than lateness due to technical difficulties verified by a GSI or Professor Dunning, **no late submissions are accepted**.  You must submit the assignment no later than 8:55 AM to receive credit.

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit.

# %%
ottr::export("Week13_Activity1.ipynb", pdf = TRUE, force_save = TRUE)
