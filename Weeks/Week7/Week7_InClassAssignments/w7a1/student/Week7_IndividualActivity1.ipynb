# %% [markdown]
# # POLISCI 3
#
# ## Week 7, Individual Activity 1: Using Confidence Intervals

# %% [markdown]
# Today we'll be analyzing the same dataset as we looked at the end of Notebook Lecture 1.
#
# At its 2014 precinct conventions, the Utah Republican Party tried to encourage women to run for state delegate.
#
# Let's read in the data...

# %%
#RUN THIS CELL
library(testthat)
library(estimatr)

data <- read.csv('ps3_week7_electing_women.csv')
head(data)

# %% [markdown]
# Here is a quick reminder of what each column means:
#
# - `unique_id`: Precinct ID
# - `treat`: treatment variable
#     - `'control'`: control group
#     - `'supply'`: supply group; party chair instructed to recruit 2-3 women
#     - `'demand'`: demand group; party chair reads letter at precinct convention
#     - `'both'`: a fourth group getting both the supply and demand treatments; party chair instructed to read letter *and* to recruit 2-3 women
# - `prop_sd_fem2014`: Proportion of 2014 elected state delegates from that precinct who were women
# - `sd_onefem2014`: 1 if at least one woman was selected; 0 otherwise
# - `county` : County name in Utah
# - `pc_male`: 1 if precinct chair is male; 0 otherwise (precinct chair is person who runs precinct meeting, would read letter if assigned to do so, etc.)

# %% [markdown]
# ----
#
# **Question 1a (1.5 points).** Use the `difference_in_means()` function to estimate the effect of the "supply" condition relative to the control group on the `sd_onefem2014` outcome. Store the result in `supply.vs.control`.
#
# For this question, you will be able to see if you've gotten the right answer by running the "ottr" cell after your answer.  If you don't get it right (i.e., you don't see "All tests passed!"), try again!

# %%
supply.vs.control <- difference_in_means(...)
supply.vs.control # Let's look at the answer you calcualted.

# %%
. = ottr::check("tests/q1a.R")

# %% [markdown]
# **Review of p-values** Now, let's print the p-value you found in Question 1a.  You can use `$p.value` after the output of the function to print the value, like this:

# %%
# RUN THIS CELL

supply.vs.control$p.value

# %% [markdown]
# **Question 1b. (1 point)**  Which of the following is **not** a correct statement, given the p-value in this experiment?
#
# - `'a'` The estimated effect of the supply condition is statistically significant.
#
# - `'b'` It is likely that an effect as big as the one we estimated could arise simply by chance, if the null hypothesis of no effect were true.
#
# - `'c'` Using the conventional threshold, we will reject the null hypothesis of no effect in favor of the alternative hypothesis of a non-zero effect.
#
# - `'d'` It is possible that there is no true effect, i.e., that the true average treatment effect is zero.
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q1b.answer <- 'a'`.

# %%
q1b.answer <- '...'
q1b.answer # Print your answer

# %% [markdown]
# -----
#
# **Question 2 (1 point).** As noted above, the professors who ran the study were optimistic that the "supply" approach might have a large effect on the number of women elected. But, now that they've run the experiment, how optimistic does the data allow them to be?
#
# Extract the top of the 95% confidence interval for the effect of the "supply" treatment from the `supply.vs.control` variable you made in Question 2. Save the results in the variable `supply.vs.control.ci.top`.
#
# **Retrieve the top of the confidence interval from `supply.vs.control` using code; do NOT copy and paste it.**

# %%
supply.vs.control.ci.top <- NULL # YOUR CODE HERE
supply.vs.control.ci.top # Let's look at the answer you calcualted.

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# -----
#
# **Question 3 (1 point).** Now, save the bottom of the 95% confidence interval.
#
# That is, extract the bottom of the 95% confidence interval for the effect of the supply treatment from the `supply.vs.control` variable you made in Question 1. Save the results in the variable `supply.vs.control.ci.bottom`.
#
# **Retrieve the bottom of the confidence interval from `supply.vs.control` using code; do NOT copy and paste it.**

# %%
supply.vs.control.ci.bottom <- NULL # YOUR CODE HERE
supply.vs.control.ci.bottom # Let's look at the answer you calcualted.

# %% [markdown]
# <!-- END QUESTION -->
#
# ------
#
# **Question 4 (1 point).** The state party Vice Chair is an optimist about the "supply" letters --- thinking that they have a large effect --- and says that the party should send the "supply" letters to all 2,500 precincts in an upcoming election. In this "best case scenario", how many additional precincts of the 2,500 in the new election could we expect to elect at least one woman? Use the top of the 95% confidence interval to answer the question.
#
# *Hint: Use the variable you calculated in question 2!*  **Make sure to use the variable you created above (don't type in the raw numbers).**  If you have questions about how to do this, see the end of Week 7, Notebook Lecture 1!

# %%
additional.precincts <- NULL # YOUR CODE HERE
additional.precincts

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ------
#
# **Question 5 (1 point).** The Chair of the party needs to make a decision about whether to send out the "supply" letters to the 2,500 precincts in the upcoming election. The Chair has heard from the Vice Chair (an optimist about the letters) that the letters have the potential to cause hundreds of precincts to elect women that otherwise wouldn't elect any women. But the Chair has also heard from the Secretary who worries that these letters will backfire and actually cause *fewer* precincts to elect women.
#
# The Chair hasn't taken a statistics class but needs to make a decision and wants to know what you think of the evidence overall.
#
# Below you will find messages you could write to the Chair of the party that explain what the evidence we saw in Questions 1-4 above says.
#
# **Choose the answer below that is NOT correct** (and/or that offers incorrect reasoning or incorrect summary of the results of the study).
#
# - `'a'` Dear Chair: In the most optimistic scenario, sending 2,500 letters could cause over three hundred additional precincts which would not have done so otherwise to elect women delegates.  But it is likely that the true effect of sending the letters could be zero.
#
# - `'b'` Dear Chair: It is plausible that the effect of sending 2,500 letters could be nearly zero, but it is at least as plausible that this could cause over three hundred additional precincts which would not have done so otherwise to elect women delegates.
#
# - `'c'` Dear Chair: Although the effect of the mailers is statistically significant in the study, it is possible that the true effect is zero or negative.
#
# - `'d'` Dear Chair: It seems unlikely that the letters would "backfire" by producing a negative effect, but it is possible the impact of the letters won't be particularly large.
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q5.answer <- 'a'`.

# %%
q5.answer <- '...'
q5.answer # print your answer

# %% [markdown]
# <!-- END QUESTION -->
#
# ------
#
# **Question 6a (1 point).** Which of the following is **NOT** correct?
#
# - `'a'`: There is a 95% chance that the confidence interval from an experiment will contain the true average treatment effect.
# - `'b'`: The top of the confidence interval calculated in Question 2 captures the most optimistic effect size (of the "supply" treatment) that is plausible given the data.
# - `'c'`: In Question 1, if the standard error of the experiment were smaller, the confidence interval would be narrower (i.e., the top and bottom numbers would be closer together).
# - `'d'`: The top of the confidence interval calculated in Question 2 gives our best guess for the true average treatment effect (of the "supply" treatment).
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q6.answer <- 'a'`.

# %%
q6a.answer <- '...'
q6a.answer # print your answer

# %% [markdown]
# ------
#
# **Question 6b (1 point).** Which of the following is **NOT** correct (or choose the least correct answer)?
#
# - `'a'`: In moderately large experiments, the probability histogram of the difference of averages between the treatment and control groups is approximately normally distributed.
# - `'b'`: In moderately large experiments, the outcome variable is approximately normally distributed.
# - `'c'`: In moderately large experiments, the sampling distribution of the difference of averages between the treatment and control groups is approximately normally distributed.
# - `'d'`: In moderately large experiments, if the null hypothesis is true and if we repeat the experiment over and over, we expect about 95% of the differences of averges between the treatment and control groups to lie between 1.96 and -1.96 standard errors of 0.
#
# Enter your answer below between quotes. For example, if you wanted to answer `'a'`, your answer would look like: `q6b.answer <- 'a'`.

# %%
q6b.answer <- '...'
q6b.answer # print your answer

# %% [markdown]
# ------
#
# **Question 7 (0.5 points).** `TRUE` or `FALSE`: Given the same standard error, an increase in the estimate may change the width of the confidence interval (i.e., the distance between the upper end minus lower end).
#
# Enter your answer below without quotes. For example, if you wanted to answer `TRUE`, you would write `q7.answer <- TRUE`.

# %%
q7.answer <- NULL # YOUR CODE HERE
q7.answer # print your answer

# %% [markdown]
# ——
#
# # Submitting Your Notebook (please read carefully!)
#
# To submit your notebook...
#
# ### 1. Click `File` $\rightarrow$ `Save Notebook`.
#
# ### 2. Wait 5 seconds.
#
# ### 3. Select the cell below and hit run.

# %%
ottr::export("Week7_IndividualActivity1.ipynb")

# %% [markdown]
# After you hit "Run" on the cell above, click the download link. A .zip file should download to your computer.
#
# (If you make changes to your notebook, you'll need to hit save and then run the cell above again before you submit to get a new version of it.)
#
# ### 4. Submit the .zip file you just downloaded <a href="https://www.gradescope.com/" target="_blank">on Gradescope here</a>.
#
# Notes:
#
# - **This does not seem to work on Chrome for iPad or iPhone.** If you're using an iPad or iPhone, you need to download the file using **Safari**.
# - If your web browser automatically unzips the .zip file (so you see a folder instead of a .zip file), you can just upload the .ipynb file that is inside the folder.
# - If this method is not working for you, try this: hit `File`, then `Download as`, then and submit the `Notebook (.ipynb)` file.
# - **If you are having technical difficulties** (i.e., you can't download your zip file or can't upload the file to Gradescope), **raise your hand to show your GSI immediately and email your Notebook (.ipynb) file to your GSI**. Do this before the assignment is due at 8:45 AM and definitely no later than 8:50 AM!
# - **No late submissions are accepted** (i.e. **no submissions allowed after 8:50 AM**). Note that assignments are due at 8:45 AM but the submission window on Gradescope closes at 8:50 AM. So 8:50 AM is the final time you can submit either on Gradescope (or to your GSI if you had technical problems).

# %% [markdown]
# ----

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit.

# %%
ottr::export("Week7_IndividualActivity1.ipynb", pdf = TRUE, force_save = TRUE)
