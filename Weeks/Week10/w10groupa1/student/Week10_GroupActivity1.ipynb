# %% [markdown]
# # POLSCI 3
#
# ## Week 10, Group Activity 1: Difference-in-differences designs

# %% [markdown]
# **This group activity is the same as the individual activity but allows you to check your answers so you can discuss them with your group members.**
#
# **The in-class activity today focuses on conceptual interpretation of a difference-in-differences design.**

# %%
# RUN THIS CELL
library(testthat)
library(estimatr)

# %% [markdown]
# Today we'll examine a <a href="https://www.journals.uchicago.edu/doi/abs/10.1086/714932">study</a> from political scientists Andrew Hall and Jesse Yoder, who study the effects of home ownership on political behavior -- in particular, whether owning a home _causes_ people to be more likely to vote.
#
# This is obviously a difficult question to study. Simply comparing people who do and do not own homes would be a bad idea because of the potential for omitted variable bias: people who buy homes might differ in all kinds of ways (most obviously in terms of economic resources) and these background variables might also influence whether they turn out to vote.
#
# Yet, it's difficult to run an experiment on home ownership -- it's not really practical to randomly assign some people to get homes and not others.
#
# Hall and Yoder therefore use a _difference-in-differences_ design.
#
# > We combine administrative data on more than 18 million voters in Ohio and North Carolina with deed-level data on property ownership. The resulting ... dataset allows us to track when individuals become homeowners and to see how often they turn out to vote in local and national elections. Using a ... difference-in-differences design to account for pre-existing differences between homeowners and non-homeowners, we find that becoming a homeowner substantially increases an individual’s propensity to participate in local elections.
#
# In other words, Hall and Yoder track the same people over time as some buy homes and others don't, then they look at how likely they are to vote in each year. Here, the "treatment" is buying a home and the outcome is voter turnout.
#
# Here's what the results look like when they examine people who bought homes between local elections in 2007 and 2009 (solid line) and those who did not (dashed line):
#
# <img src="HallYoder.png" width="60%">
#
# This evidence comes from Ohio. Local elections happen in odd years in Ohio, so the first post-treatment election (i.e. the first election after the people being compared either did or did not buy a home in the time period analyzed) is 2009.
#
# It looks from the figure as though while there is no immediate effect. Note that homeowners are in fact *less* likely to vote in the 2009 election.  But after 2009, the solid line diverges positively from the dashed line, indicating that those who became homeowner
#
# As for the pre-treatment trends (i.e. voting in 2007 and before), note that as described on pp. 356-7 of the paper (linked <a href="https://www.journals.uchicago.edu/doi/abs/10.1086/714932">here</a>), this figure involves data where homeowners are matched to non-homeowners with similar voting histories in the pre-treatment period---which is one reason the pre-treatment trends look so similar.
#
# Later in today's activity, we'll look at what pre-treatments trends look like when we **don't** do such matching first.
#
# Based on this evidence, Hall and Yoder conclude that becoming a homeowner _causes_ "about a 4.9 percentage point increase in turnout in local general elections."
#
# **In this activity, you will think about and answer some conceptual questions about this study and about difference-in-difference designs in general**.
#
# You'll attempt to read in the data, so you can have a look at how it is structured.  But **we won't actually analyze the data set in the context of the in-class activity** (it is very large and so the computational resources required for us all to work with the data at the same time are substantial).

# %% [markdown]
# -----
#
# **Question 1 (1 point).** Consider the following averages:
#
# - (A) Average voter turnout in the 2009 elections of people who bought homes between the 2007 and 2009 elections;
# - (B) Average voter turnout in the 2009 elections of people who do not own their homes;
# - (C) Average voter turnout in the 2007 elections of the people who went on to buy their homes between the 2007 and 2009 elections; and
# - (D) Average voter turnout in the 2007 elections of the people who do not own (and do not go on to buy) their homes.
#
# Which of the following describes a difference-in-differences analysis that Hall and Yoder can use to estimate the effect of homeownership?
#
# - `'a'` (A - B) - (C - D).
# - `'b'` (A - C) - (B - D).
# - `'c'`  Both `'a'` or `'b'` are correct.  They are mathematically equivalent.
# - `'d'`  Neither `'a'` nor `'b'` is correct.  Neither answer describes an appropriate difference-in-differences analysis.
#
# Pick the best answer.  For example, if you want to pick option `'a'`, you would write `q1.answer <- 'a'`.

# %%
q1.answer <- '...'
q1.answer # print your answer

# %%
. = ottr::check("tests/q1.R")

# %% [markdown]
# ------
#
# **Question 2 (1 point).** Stanford Professor Imbe Cill says that the authors should have simply compared voter turnout among those who do and do not own homes rather than conduct this "differences-in-differences" study. Why is Hall and Yoder's study is more persuasive than the study Professor Cill is proposing?
#
# 1. People who own and do not own homes may be different in other ways to begin with, so Professor Cill's proposed study potentially contains omitted variable bias.
# 2. Hall and Yoder’s approach contains no bias from pre-existing differences between people who later buy and do not buy homes.
#
# - `'a'`: 1. only
# - `'b'`: 2. only
# - `'c'`: Both 1. and 2.
# - `'d'`: Neither 1. nor 2.
#
# Enter your answer below between quotes. For example, if you wanted to answer 'a', your answer would look like: `q2.answer <- 'a'`.

# %%
q2.answer <- '...'
q2.answer # print your answer

# %%
. = ottr::check("tests/q2.R")

# %% [markdown]
# ------
#
# **Question 3 (1 point).** Which of the following is **NOT** a correct statement about Hall and Yoder's difference-in-differences design?
#
# - `'a'` Bias in the estimate of treatment effects would arise if the kind of person who buys a home between the 2007 and 2009 elections was more likely to have just gotten a new job (allowing them to afford the home), and if the job and additional income lead them to vote more in 2009.
# - `'b'` Bias in the estimate of treatment effects would arise if there are any pre-existing (i.e., baseline or pre-treatment) differences between homeowners and non-homeowners.
# - `c'` Here, the "parallel trends" assumption means that, if owning a home had no effect, the changes between 2007 and 2009 in the voter turnout rates of the people who do and do not buy homes would be similar.
# - `'d'` Here, the "parallel trends" assumption means that the change in the control group tells us what the counterfactual change in the treatment group would have been, if those in the treatment group had not bought homes.
#
# Enter your answer below between quotes. For example, if you wanted to answer 'a', your answer would look like: `q3.answer <- 'a'`.

# %%
q3.answer <- '...'
q3.answer # print your answer

# %%
. = ottr::check("tests/q3.R")

# %% [markdown]
# ------
#
# **Question 4 (1 point).** Which of the following is / are example(s) of a "placebo test" Hall and Yoder could run to help bolster confidence that the "parallel trends" assumption in their data holds?
#
# 1. Checking if the two groups have a similar number of children before 2007
# 2. Checking if the two groups pay a similar amount in property taxes after 2009
# 3. Checking if the two groups have a similar turnout rate after 2009
#
# - `'a'`: 1. only
# - `'b'`: 1. and 2.
# - `'c'`: 1., 2., and 3.
# - `'d'`: None of the above.
#
# Enter your answer below between quotes. For example, if you wanted to answer 'a', your answer would look like: `q4.answer <- 'a'`.

# %%
q4.answer <- '...'
q4.answer # print your answer

# %%
. = ottr::check("tests/q4.R")

# %% [markdown]
# Now, read in data from the Hall and Yoder study. **If you have trouble reading in the data, don't worry -- you will answer only conceptual questions in the remainder this activity, and the data are summarized in the codebook below.**
#
# The codebook and the description of the design above is all you need to answer the remaining questions. You can also go on and answer the conceptual questions below while the data are still loading.

# %%
# RUN THIS CELL

# It may take a few minutes for the data set to load because it is very large (there are around 4 million observations)

hall_yoder <- read.csv("/home/jovyan/_shared/bcourses-1550624-readonly/hall_yoder_wide.csv")
head(hall_yoder)

# %% [markdown]
# **Codebook**---here's what the variables mean:
#
# - `id`: this is a unique id number for each person in the dataset
# - `treat`: this variable equals 1 if the person became a homeowner between 2007 and 2009; otherwise, it equals 0, which means the person is not a homeowner.
# - `delta_turnout_0709`: this is an outcome variable; it is the change in the person's turnout between the 2007 and 2009 elections. If it equals 0, it is either because the person voted in both elections or neither; if it is 1, the person voted in 2009 but not 2007; if it is -1, the person voted in 2007 but not 2009.
#
# The other `delta_turnout_XXXX` variables are defined similarly as `delta_turnout_0709`.  Thus, we have several variables that measure the change in outcomes over a longer time period:
# - `delta_turnout_0711` is the change in the person's turnout betwen 2007 and 2011;
# - `delta_turnout_0713` is the change in the person's turnout betwen 2007 and 2013;
# - `delta_turnout_0715` is the change in the person's turnout betwen 2007 and 2015;
# - `delta_turnout_0717` is the change in the person's turnout betwen 2007 and 2017;
#
# Finally, there are several variables that measure the change in a person's turnout between two elections, prior to the period of treatment (when the person became a homeowner or not):
# - `delta_turnout_0103` is the change in the person's turnout between 2001 and 2003;
# - `delta_turnout_0305` is the change in the person's turnout between 2003 and 2005;
# - `delta_turnout_0507` is the change in the person's turnout betwen 2005 and 2007;

# %% [markdown]
# First, let's analyze the effect of becoming a homeowner between 2007 and 2009 on turnout in the 2009 election.

# %% [markdown]
# Thus, we'll do a difference-in-differences analysis by using the `difference_in_means()` function to estimate the effect of becoming a homeowner between 2007 and 2009 on the change in turnout between the 2007 and the 2009 election.
#
# Note that the `treat` variable is a 0-1 variable, as defined in the codebook.  For the outcome variable, we use the change in turnout between 2007 and 2009. Remember that the average of the outcome variable in a given group gives the change in average turnout--i.e., the change in the turnout rate---in that group.  For example, if the average change in a group is 0.025, it means that turnout increased 2.5 percentage points. (To turn a rate into percentage points, we multiply by 100).
#
# Here are the results:
#
# <img src="diff_in_diff_0709.png" width="100%">

# %% [markdown]
# **Question 5 (1 point)**: Which of the following is **NOT** a correct interpretation of the results in Question 5?
#
# - `'a'` The estimated effect of buying a home between 2007 and 2009 is highly statistically significant.
# - `'b'` The true effect of buying a home between 2007 and 2009 is highly statistically significant.
# - `'c'` The *p*-value is much smaller than 0.05. Thus, if the null hypothesis of no effect is correct, it would be very unlikely to observe the estimate that we do.
# - `'d'` Our best guess is that homeownership decreased turnout by about 1.5 percentage points.
#
# Enter your answer below between quotes. For example, if you wanted to answer 'a', your answer would look like: `q5.answer <- 'a'`.

# %%
q5.answer <- '...'
q5.answer # print your answer

# %%
. = ottr::check("tests/q5.R")

# %% [markdown]
# Now, let's do a difference-in-differences analysis by using the `difference_in_means()` function to estimate the effect of becoming a homeowner between 2007 and 2009 on four more outcome variables:
# - the change in turnout between the 2007 and the 2011 election;
# - the change in turnout between the 2007 and the 2013 election;
# - the change in turnout between the 2007 and the 2015 election; and
# - the change in turnout between the 2007 and the 2017 election.
#
# Let's see what the results look like. First for **the change in turnout between the 2007 and the 2011 election**:
#
# <img src="diff_in_diff_0711.png" width="80%">
#
#
#
# Next, **the change in turnout between the 2007 and the 2013 election**:
#
# <img src="diff_in_diff_0713.png" width="80%">
#
#
#
# Next, **the change in turnout between the 2007 and the 2015 election**:
#
# <img src="diff_in_diff_0715.png" width="80%">
#
#
#
# Finally, **the change in turnout between the 2007 and the 2017 election**:
#
# <img src="diff_in_diff_0717.png" width="80%">

# %% [markdown]
# **Question 6 (1 point)**.  Which of the following statements is **NOT** consistent with the evidence we have seen so far?
#
# - `'a'` There may have been an initial disruptive effect of homeownership, causing a decline in voter turnout in the immediate post-treatment election.  But the evidence suggests that ownership caused the difference in turnout between those who bought homes between 2007 and 2009, and those who did not own homes, to stabilize between 5 and 6 percentage points in later elections (e.g. in elections from 2013 through 2017)
# - `'b'` The *p*-values would lead us to reject the null hypothesis of no effect in all of the tests.
# - `'c'` The *t*-statistics are larger (in absolute value) than required for the standard threshold for statistical significance in all of the tests.
# - `'d'` It is logically inconsistent for the effect of homeownership on voter turnout to be both negative and positive.  There must be something wrong with the data.
#
# Enter your answer below between quotes. For example, if you wanted to answer 'a', your answer would look like: `q6.answer <- 'a'`.

# %%
q6.answer <- '...'
q6.answer # print your answer

# %%
. = ottr::check("tests/q6.R")

# %% [markdown]
# Finally, let's consider some **placebo tests** to check key assumptions of the difference-in-differences design.  Before we turn to the results of some data analysis, please answer the following conceptual question.
#
# **Question 7 (1 point)**. Consider the following statement: "If the trends in voting in the treatment and control groups are parallel in the pre-treatment period, we would expect the changes in turnout rates between 2005 and 2007 in each of the groups to be statistically indistinguishable."
#
# Is this statement true or false? Or can't we tell with the information provided?
#
# (In the statement, "statistically indististinguishable" means we cannot reject a null hypothesis of no difference. Here, the treatment group consists of those people who became homeowners between 2007 and 2009; the control group consists of those who were not and did not become homeowners).
#
# - `'a'` The statement is true.
# - `'b'` The statement is false.
# - `'c'` We cannot tell with the information provided.
#
# Enter your answer below between quotes. For example, if you wanted to answer 'a', your answer would look like: `q7.answer <- 'a'`.

# %%
q7.answer <- '...'
q7.answer # print your answer

# %%
. = ottr::check("tests/q7.R")

# %% [markdown]
# Now, let's see what we find when we actually do the placebo test discussed in Question 7, as well as two closely related placebo tests.
#
# We have written the code for you.  Here are the results:
#
# **Results for the change in turnout from 2005 to 2007:**
#
# <img src="diff_in_diff_0507.png" width="80%">
#
# **Results for the change in turnout from 2003 to 2005:**
#
# <img src="diff_in_diff_0305.png" width="80%">
#
# **Results for the change in turnout from 2001 to 2003:**
#
# <img src="diff_in_diff_0103.png" width="80%">

# %% [markdown]
# Now, please answer the following question.
#
# **Question 8 (1 point)**.  Which of the following conclusions does **NOT** follow from the results of the placebo tests?
#
# - `'a'` For two of the three placebo tests printed above, the results show statistically significant differences in the pre-treatment trends in the treatment and control group.  This suggests reason for caution in interpreting our difference-in-differences analyses of treatment effects above (e.g., using changes from 2007 to 2009, as well as from 207 to 2011, 2013, 2015, and 2017) as evidence of causal effects.
# - `'b'` In each of the placebo tests printed above, the substantive differences in the pre-treatment trends are relatively small (e.g. between 0.6 to 0.7 percentage points for the first two tests and 0.05 percentage points for the third test), especially relative to the size of the estimate treatment effects. Moreover, with nearly four million observations, even small differences tend to be statistically significant.  Thus, there may still be some convincing evidence of causal effects.
# - `'c'` Both `'a'` and `'b'` reasonably follow from the results.
# - `'d'` Neither `'a'` nor `'b'` reasonably follow from the results.
#
# Enter your answer below between quotes. For example, if you wanted to answer 'a', your answer would look like: `q8.answer <- 'a'`.

# %%
q8.answer <- '...'
q8.answer # print your answer

# %%
. = ottr::check("tests/q8.R")

# %% [markdown]
# --------
#
# # Submitting Your Notebook (please read carefully!)
#
# To submit your notebook...
#
# ### 1. Click `File` $\rightarrow$ `Save Notebook`.
#
# ### 2. Wait 5 seconds.
#
# ### 3. Select the cell below and hit run.

# %%
ottr::export("Week10_GroupActivity1.ipynb", pdf = TRUE, force_save = TRUE)

# %% [markdown]
# After you hit "Run" on the cell above, click the download link. A .zip file should download to your computer.
#
# (If you make changes to your notebook, you'll need to hit save and then run the cell above again before you submit to get a new version of it.)
#
# ### 4. Submit the .zip file you just downloaded <a href="https://www.gradescope.com/" target="_blank">on Gradescope here</a>.
#
# Notes:
#
# - **This does not seem to work on Chrome for iPad or iPhone.** If you're using an iPad or iPhone, you need to download the file using **Safari**.
# - If your web browser automatically unzips the .zip file (so you see a folder instead of a .zip file), you can just upload the .ipynb file that is inside the folder.
# - If this method is not working for you, try this: hit `File`, then `Download as`, then and submit the `Notebook (.ipynb)` file.
# - **If you are having technical difficulties** (i.e., you can't download your zip file or can't upload the file to Gradescope), **raise your hand to show your GSI immediately and email your Notebook (.ipynb) file to your GSI**. Do this before the assignment is due at 8:45 AM and definitely no later than 8:50 AM!
# - **No late submissions are accepted** (i.e. **no submissions allowed after 8:50 AM**). Note that assignments are due at 8:45 AM but the submission window on Gradescope closes at 8:50 AM. So 8:50 AM is the final time you can submit either on Gradescope (or to your GSI if you had technical problems).

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit.

# %%
ottr::export("Week10_GroupActivity1.ipynb", pdf = TRUE, force_save = TRUE)
